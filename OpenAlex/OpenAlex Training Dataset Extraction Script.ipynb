# %% [markdown]
# #### 1. Get the Title - Key poistive pairs

# %%
import requests
import json
import time

def fetch_and_store_data(url, output_file):
    # Fetch data from the URL
    response = requests.get(url)
    data = response.json()

    # Extract relevant information and store in the desired format
    results = data.get("results", [])
    formatted_data = []

    for result in results: 
        title = result.get("title", "")
        keywords = result.get("keywords", [])

        if keywords:
            # Extracting the top-scored keyword text
            top_keyword = keywords[0].get("keyword", "")
            # Creating the structure {"texts": ["title", "key"]}
            formatted_entry = {"texts": [title, top_keyword]}
            formatted_data.append(formatted_entry)

    # Write to a .jsonl file
    with open(output_file, "a") as jsonl_file:
        for entry in formatted_data:
            jsonl_file.write(json.dumps(entry) + "\n")

        # Delay for 1 second before the next API call due to rate limit
        # time.sleep(delay) 

if __name__ == "__main__":
    # Specify the URL and output file
    # api_url = "https://api.openalex.org/works?mailto=brookshum24@gmail.com&sample=10000&seed=3&select=title,keywords"
    # Initialize counters
    current_page = 1
    total_entries_count = 0
    target_count = 10000
    # Specify the URL and output file
    output_jsonl_file = "title_key.jsonl"

    # Loop until the target count is reached
    while total_entries_count < target_count: 
        api_url = f"https://api.openalex.org/works?mailto=brookshum24@gmail.com&page={current_page}&per_page=25&select=title,keywords"
        # Fetch and store the data
        fetch_and_store_data(api_url, output_jsonl_file)
        current_page +=1
        total_entries_count += 25
    print(f"Total entries written to {output_jsonl_file}: {total_entries_count}")

# %% [markdown]
# #### 2. Get the Title - Abstract positive pairs

# %%
import requests
import json
import time

def fetch_and_store_data(url, output_file):
    # Fetch data from the URL
    response = requests.get(url)
    data = response.json()

    # Extract relevant information and store in the desired format
    results = data.get("results", [])
    formatted_data = []
    
    for result in results:
        title = result.get("title", "")
        abstract_index = result.get("abstract_inverted_index")
        
        # Skip processing if abstract_inverted_index is None
        if abstract_index is None:
            continue
       
        # Concatenate all keys from the abstract_inverted_index using spaces
        abstract_text = " ".join(key for key in abstract_index.keys())

        # Creating the structure {"texts": ["title", "abstract"]}
        formatted_entry = {"texts": [title, abstract_text]}
        formatted_data.append(formatted_entry)

    # Write to a .jsonl file
    with open(output_file, "a") as jsonl_file:
        for entry in formatted_data:
            jsonl_file.write(json.dumps(entry) + "\n") 

if __name__ == "__main__":
    # Initialize counters
    current_page = 1
    total_entries_count = 0
    target_count = 10000
    # Specify the URL and output file
    output_jsonl_file = "title_abstract.jsonl"

    # Loop until the target count is reached
    while total_entries_count < target_count: 
        api_url = f"https://api.openalex.org/works?mailto=brookshum24@gmail.com&page={current_page}&per_page=25&select=title,abstract_inverted_index"
        # Fetch and store the data
        fetch_and_store_data(api_url, output_jsonl_file)
        current_page +=1
        total_entries_count += 25
    print(f"Total entries written to {output_jsonl_file}: {total_entries_count}")
# Out:
# Total entries written to title_abstract.jsonl: 10000

# %% [markdown]
# #### 3. Get the Expanded Referenced , Related and Ngrams from Work,Object and save as a dataframe [Max 3 values]

# %% [markdown]
# ##### Import necessary packages

# %% [markdown]
# ##### SQLite for in-browser Database

# %%
! pip install db-sqlite3
# Out:
# Requirement already satisfied: db-sqlite3 in /opt/conda/lib/python3.10/site-packages (0.0.1)
# Requirement already satisfied: db in /opt/conda/lib/python3.10/site-packages (from db-sqlite3) (0.1.1)
# Requirement already satisfied: antiorm in /opt/conda/lib/python3.10/site-packages (from db->db-sqlite3) (1.2.1)

# %% [markdown]
# ##### [*Voyage AI*](https://docs.voyageai.com/docs/introduction) provides cutting-edge embedding/vectorizations models. It is first in clustering task currently on the MTEB board.

# %%
# !pip install voyageai
# Out:
# Requirement already satisfied: voyageai in /opt/conda/lib/python3.10/site-packages (0.1.7)
# Requirement already satisfied: aiohttp<4.0,>=3.5 in /opt/conda/lib/python3.10/site-packages (from voyageai) (3.9.1)
# Requirement already satisfied: aiolimiter<2.0.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from voyageai) (1.1.0)
# Requirement already satisfied: numpy>=1.11 in /opt/conda/lib/python3.10/site-packages (from voyageai) (1.25.2)
# Requirement already satisfied: requests<3.0,>=2.20 in /opt/conda/lib/python3.10/site-packages (from voyageai) (2.31.0)
# Requirement already satisfied: tenacity>=8.0.1 in /opt/conda/lib/python3.10/site-packages (from voyageai) (8.2.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0,>=3.5->voyageai) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0,>=3.5->voyageai) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0,>=3.5->voyageai) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0,>=3.5->voyageai) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0,>=3.5->voyageai) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0,>=3.5->voyageai) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.20->voyageai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.20->voyageai) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.20->voyageai) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.20->voyageai) (2023.11.17)

# %% [markdown]
# #### Fetch 20k sample and Extract the expanded form of Referenced , Related and Ngrams of the Work Object

# %%
import requests
import json
import pandas as pd

# Function to fetch and process referenced works
def fetch_extract_works(work_id):
    # Initialize an empty list to store referenced work titles
    referenced_work_titles = []
    related_work_titles = []
    ngrams_list = []

    # Fetch the work details
    work_url = f"https://api.openalex.org/works/{work_id}"
    response = requests.get(work_url)

    try:
        response.raise_for_status()
        work_details = response.json()
    except Exception as e:
        return None, None, None, None

    work_title = work_details.get("title")

    # Extract and process referenced works
    referenced_works = work_details.get("referenced_works", [])[:3]  # Limit to the first 3 references
    for referenced_work_url in referenced_works:
        # Extract the last section of the work ID from the URL
        last_section = referenced_work_url.rsplit("/", 1)[-1]

        # Construct the referenced_work_api_url
        referenced_work_api_url = f"https://api.openalex.org/works/{last_section}"

        # Fetch details of the referenced work
        referenced_work_response = requests.get(referenced_work_api_url)

        try:
            referenced_work_response.raise_for_status()
            referenced_work_details = referenced_work_response.json()
        except Exception as e:
            referenced_work_titles.append("")
            continue

        # Extract title as a string and add to the list
        referenced_work_title = str(referenced_work_details.get("title", ""))
        referenced_work_titles.append(referenced_work_title)

    # Extract and process related works
    related_works = work_details.get("related_works", [])[:3]  # Limit to the first 3 related works
    for related_work_url in related_works:
        # Extract the last section of the work ID from the URL
        last_section = related_work_url.rsplit("/", 1)[-1]

        # Construct the related_work_api_url
        related_work_api_url = f"https://api.openalex.org/works/{last_section}"

        # Fetch details of the related work
        related_work_response = requests.get(related_work_api_url)

        try:
            related_work_response.raise_for_status()
            related_work_details = related_work_response.json()
        except Exception as e:
            related_work_titles.append("")
            continue

        # Extract title as a string and add to the list
        related_work_title = str(related_work_details.get("title", ""))
        related_work_titles.append(related_work_title)

    # Fetch ngrams data
    ngrams_url = f"https://api.openalex.org/works/{work_id}/ngrams"
    ngrams_response = requests.get(ngrams_url)

    try:
        ngrams_response.raise_for_status()
        ngrams_data = ngrams_response.json().get("ngrams", [])
    except Exception as e:
        ngrams_list.extend([""] * 3)
        ngrams_data = []

    # Check if ngrams_data is not empty before sorting
    if ngrams_data:
        # Sort ngrams_data by term_frequency in descending order
        ngrams_data.sort(key=lambda x: x.get("term_frequency", 0), reverse=True)

        # Select only the top 3 ngrams
        selected_ngrams = [ngram.get("ngram", "") for ngram in ngrams_data[:3]]
        ngrams_list.extend(selected_ngrams)

    return work_title, referenced_work_titles, related_work_titles, ngrams_list

# Create an empty DataFrame
# Create an empty DataFrame with the required columns
columns = ["work_id", "title", "referenced_works", "related_work_titles", "ngrams", "nearest_related_work", "nearest_referenced_work", "nearest_ngrams_work"]
wrangled_work_df = pd.DataFrame(columns=columns)

# Initialize cursor for pagination
cursor = "*"

max_data_cap = 20000

# Fetch 20k results using cursor pagination , no seeding for randomness in subsequent fetches
while len(wrangled_work_df) < max_data_cap:
    # Fetch the sample work IDs with cursor
    works_url = f"https://api.openalex.org/works?mailto=brookshum24@gmail.com&sample=10000&select=id&cursor={cursor}"
    works_response = requests.get(works_url)
    
    try:
        works_response.raise_for_status()
        works_data = works_response.json()
    except Exception as e:
        print(e)
        continue

    # Extract IDs from the results list
    work_ids = [work.get("id", "").rsplit("/", 1)[-1] for work in works_data.get("results", [])]
    
    print(f"Number of Work Objects to use: {len(work_ids)}")

    # Fetch and process referenced, related works, and ngrams for each work ID
    for work_id in work_ids:
        work_title, referenced_work_titles, related_work_titles, ngrams_list = fetch_extract_works(work_id)

        # Add a row to the DataFrame
        wrangled_work_df = pd.concat([wrangled_work_df, pd.DataFrame({
            "work_id": [work_id],
            "title": [work_title],
            "referenced_works": [referenced_work_titles],
            "related_work_titles": [related_work_titles],
            "ngrams": [ngrams_list]
        })], ignore_index=True)
        
        # Add a progress bar
        print(f"Dataframe Progress: Added {len(wrangled_work_df)} out of {max_data_cap}")
# Out:
# Number of Work Objects to use: 25
# Dataframe Progress: Added 1 out of 20000
# Dataframe Progress: Added 2 out of 20000
# Dataframe Progress: Added 3 out of 20000
# Dataframe Progress: Added 4 out of 20000
# Dataframe Progress: Added 5 out of 20000
# Dataframe Progress: Added 6 out of 20000
# Dataframe Progress: Added 7 out of 20000
# Dataframe Progress: Added 8 out of 20000
# Dataframe Progress: Added 9 out of 20000
# Dataframe Progress: Added 10 out of 20000
# Dataframe Progress: Added 11 out of 20000
# Dataframe Progress: Added 12 out of 20000
# Dataframe Progress: Added 13 out of 20000
# Dataframe Progress: Added 14 out of 20000
# Dataframe Progress: Added 15 out of 20000
# Dataframe Progress: Added 16 out of 20000
# Dataframe Progress: Added 17 out of 20000
# Dataframe Progress: Added 18 out of 20000
# Dataframe Progress: Added 19 out of 20000
# Dataframe Progress: Added 20 out of 20000
# Dataframe Progress: Added 21 out of 20000
# Dataframe Progress: Added 22 out of 20000
# Dataframe Progress: Added 23 out of 20000
# Dataframe Progress: Added 24 out of 20000
# Dataframe Progress: Added 25 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 26 out of 20000
# Dataframe Progress: Added 27 out of 20000
# Dataframe Progress: Added 28 out of 20000
# Dataframe Progress: Added 29 out of 20000
# Dataframe Progress: Added 30 out of 20000
# Dataframe Progress: Added 31 out of 20000
# Dataframe Progress: Added 32 out of 20000
# Dataframe Progress: Added 33 out of 20000
# Dataframe Progress: Added 34 out of 20000
# Dataframe Progress: Added 35 out of 20000
# Dataframe Progress: Added 36 out of 20000
# Dataframe Progress: Added 37 out of 20000
# Dataframe Progress: Added 38 out of 20000
# Dataframe Progress: Added 39 out of 20000
# Dataframe Progress: Added 40 out of 20000
# Dataframe Progress: Added 41 out of 20000
# Dataframe Progress: Added 42 out of 20000
# Dataframe Progress: Added 43 out of 20000
# Dataframe Progress: Added 44 out of 20000
# Dataframe Progress: Added 45 out of 20000
# Dataframe Progress: Added 46 out of 20000
# Dataframe Progress: Added 47 out of 20000
# Dataframe Progress: Added 48 out of 20000
# Dataframe Progress: Added 49 out of 20000
# Dataframe Progress: Added 50 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 51 out of 20000
# Dataframe Progress: Added 52 out of 20000
# Dataframe Progress: Added 53 out of 20000
# Dataframe Progress: Added 54 out of 20000
# Dataframe Progress: Added 55 out of 20000
# Dataframe Progress: Added 56 out of 20000
# Dataframe Progress: Added 57 out of 20000
# Dataframe Progress: Added 58 out of 20000
# Dataframe Progress: Added 59 out of 20000
# Dataframe Progress: Added 60 out of 20000
# Dataframe Progress: Added 61 out of 20000
# Dataframe Progress: Added 62 out of 20000
# Dataframe Progress: Added 63 out of 20000
# Dataframe Progress: Added 64 out of 20000
# Dataframe Progress: Added 65 out of 20000
# Dataframe Progress: Added 66 out of 20000
# Dataframe Progress: Added 67 out of 20000
# Dataframe Progress: Added 68 out of 20000
# Dataframe Progress: Added 69 out of 20000
# Dataframe Progress: Added 70 out of 20000
# Dataframe Progress: Added 71 out of 20000
# Dataframe Progress: Added 72 out of 20000
# Dataframe Progress: Added 73 out of 20000
# Dataframe Progress: Added 74 out of 20000
# Dataframe Progress: Added 75 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 76 out of 20000
# Dataframe Progress: Added 77 out of 20000
# Dataframe Progress: Added 78 out of 20000
# Dataframe Progress: Added 79 out of 20000
# Dataframe Progress: Added 80 out of 20000
# Dataframe Progress: Added 81 out of 20000
# Dataframe Progress: Added 82 out of 20000
# Dataframe Progress: Added 83 out of 20000
# Dataframe Progress: Added 84 out of 20000
# Dataframe Progress: Added 85 out of 20000
# Dataframe Progress: Added 86 out of 20000
# Dataframe Progress: Added 87 out of 20000
# Dataframe Progress: Added 88 out of 20000
# Dataframe Progress: Added 89 out of 20000
# Dataframe Progress: Added 90 out of 20000
# Dataframe Progress: Added 91 out of 20000
# Dataframe Progress: Added 92 out of 20000
# Dataframe Progress: Added 93 out of 20000
# Dataframe Progress: Added 94 out of 20000
# Dataframe Progress: Added 95 out of 20000
# Dataframe Progress: Added 96 out of 20000
# Dataframe Progress: Added 97 out of 20000
# Dataframe Progress: Added 98 out of 20000
# Dataframe Progress: Added 99 out of 20000
# Dataframe Progress: Added 100 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 101 out of 20000
# Dataframe Progress: Added 102 out of 20000
# Dataframe Progress: Added 103 out of 20000
# Dataframe Progress: Added 104 out of 20000
# Dataframe Progress: Added 105 out of 20000
# Dataframe Progress: Added 106 out of 20000
# Dataframe Progress: Added 107 out of 20000
# Dataframe Progress: Added 108 out of 20000
# Dataframe Progress: Added 109 out of 20000
# Dataframe Progress: Added 110 out of 20000
# Dataframe Progress: Added 111 out of 20000
# Dataframe Progress: Added 112 out of 20000
# Dataframe Progress: Added 113 out of 20000
# Dataframe Progress: Added 114 out of 20000
# Dataframe Progress: Added 115 out of 20000
# Dataframe Progress: Added 116 out of 20000
# Dataframe Progress: Added 117 out of 20000
# Dataframe Progress: Added 118 out of 20000
# Dataframe Progress: Added 119 out of 20000
# Dataframe Progress: Added 120 out of 20000
# Dataframe Progress: Added 121 out of 20000
# Dataframe Progress: Added 122 out of 20000
# Dataframe Progress: Added 123 out of 20000
# Dataframe Progress: Added 124 out of 20000
# Dataframe Progress: Added 125 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 126 out of 20000
# Dataframe Progress: Added 127 out of 20000
# Dataframe Progress: Added 128 out of 20000
# Dataframe Progress: Added 129 out of 20000
# Dataframe Progress: Added 130 out of 20000
# Dataframe Progress: Added 131 out of 20000
# Dataframe Progress: Added 132 out of 20000
# Dataframe Progress: Added 133 out of 20000
# Dataframe Progress: Added 134 out of 20000
# Dataframe Progress: Added 135 out of 20000
# Dataframe Progress: Added 136 out of 20000
# Dataframe Progress: Added 137 out of 20000
# Dataframe Progress: Added 138 out of 20000
# Dataframe Progress: Added 139 out of 20000
# Dataframe Progress: Added 140 out of 20000
# Dataframe Progress: Added 141 out of 20000
# Dataframe Progress: Added 142 out of 20000
# Dataframe Progress: Added 143 out of 20000
# Dataframe Progress: Added 144 out of 20000
# Dataframe Progress: Added 145 out of 20000
# Dataframe Progress: Added 146 out of 20000
# Dataframe Progress: Added 147 out of 20000
# Dataframe Progress: Added 148 out of 20000
# Dataframe Progress: Added 149 out of 20000
# Dataframe Progress: Added 150 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 151 out of 20000
# Dataframe Progress: Added 152 out of 20000
# Dataframe Progress: Added 153 out of 20000
# Dataframe Progress: Added 154 out of 20000
# Dataframe Progress: Added 155 out of 20000
# Dataframe Progress: Added 156 out of 20000
# Dataframe Progress: Added 157 out of 20000
# Dataframe Progress: Added 158 out of 20000
# Dataframe Progress: Added 159 out of 20000
# Dataframe Progress: Added 160 out of 20000
# Dataframe Progress: Added 161 out of 20000
# Dataframe Progress: Added 162 out of 20000
# Dataframe Progress: Added 163 out of 20000
# Dataframe Progress: Added 164 out of 20000
# Dataframe Progress: Added 165 out of 20000
# Dataframe Progress: Added 166 out of 20000
# Dataframe Progress: Added 167 out of 20000
# Dataframe Progress: Added 168 out of 20000
# Dataframe Progress: Added 169 out of 20000
# Dataframe Progress: Added 170 out of 20000
# Dataframe Progress: Added 171 out of 20000
# Dataframe Progress: Added 172 out of 20000
# Dataframe Progress: Added 173 out of 20000
# Dataframe Progress: Added 174 out of 20000
# Dataframe Progress: Added 175 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 176 out of 20000
# Dataframe Progress: Added 177 out of 20000
# Dataframe Progress: Added 178 out of 20000
# Dataframe Progress: Added 179 out of 20000
# Dataframe Progress: Added 180 out of 20000
# Dataframe Progress: Added 181 out of 20000
# Dataframe Progress: Added 182 out of 20000
# Dataframe Progress: Added 183 out of 20000
# Dataframe Progress: Added 184 out of 20000
# Dataframe Progress: Added 185 out of 20000
# Dataframe Progress: Added 186 out of 20000
# Dataframe Progress: Added 187 out of 20000
# Dataframe Progress: Added 188 out of 20000
# Dataframe Progress: Added 189 out of 20000
# Dataframe Progress: Added 190 out of 20000
# Dataframe Progress: Added 191 out of 20000
# Dataframe Progress: Added 192 out of 20000
# Dataframe Progress: Added 193 out of 20000
# Dataframe Progress: Added 194 out of 20000
# Dataframe Progress: Added 195 out of 20000
# Dataframe Progress: Added 196 out of 20000
# Dataframe Progress: Added 197 out of 20000
# Dataframe Progress: Added 198 out of 20000
# Dataframe Progress: Added 199 out of 20000
# Dataframe Progress: Added 200 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 201 out of 20000
# Dataframe Progress: Added 202 out of 20000
# Dataframe Progress: Added 203 out of 20000
# Dataframe Progress: Added 204 out of 20000
# Dataframe Progress: Added 205 out of 20000
# Dataframe Progress: Added 206 out of 20000
# Dataframe Progress: Added 207 out of 20000
# Dataframe Progress: Added 208 out of 20000
# Dataframe Progress: Added 209 out of 20000
# Dataframe Progress: Added 210 out of 20000
# Dataframe Progress: Added 211 out of 20000
# Dataframe Progress: Added 212 out of 20000
# Dataframe Progress: Added 213 out of 20000
# Dataframe Progress: Added 214 out of 20000
# Dataframe Progress: Added 215 out of 20000
# Dataframe Progress: Added 216 out of 20000
# Dataframe Progress: Added 217 out of 20000
# Dataframe Progress: Added 218 out of 20000
# Dataframe Progress: Added 219 out of 20000
# Dataframe Progress: Added 220 out of 20000
# Dataframe Progress: Added 221 out of 20000
# Dataframe Progress: Added 222 out of 20000
# Dataframe Progress: Added 223 out of 20000
# Dataframe Progress: Added 224 out of 20000
# Dataframe Progress: Added 225 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 226 out of 20000
# Dataframe Progress: Added 227 out of 20000
# Dataframe Progress: Added 228 out of 20000
# Dataframe Progress: Added 229 out of 20000
# Dataframe Progress: Added 230 out of 20000
# Dataframe Progress: Added 231 out of 20000
# Dataframe Progress: Added 232 out of 20000
# Dataframe Progress: Added 233 out of 20000
# Dataframe Progress: Added 234 out of 20000
# Dataframe Progress: Added 235 out of 20000
# Dataframe Progress: Added 236 out of 20000
# Dataframe Progress: Added 237 out of 20000
# Dataframe Progress: Added 238 out of 20000
# Dataframe Progress: Added 239 out of 20000
# Dataframe Progress: Added 240 out of 20000
# Dataframe Progress: Added 241 out of 20000
# Dataframe Progress: Added 242 out of 20000
# Dataframe Progress: Added 243 out of 20000
# Dataframe Progress: Added 244 out of 20000
# Dataframe Progress: Added 245 out of 20000
# Dataframe Progress: Added 246 out of 20000
# Dataframe Progress: Added 247 out of 20000
# Dataframe Progress: Added 248 out of 20000
# Dataframe Progress: Added 249 out of 20000
# Dataframe Progress: Added 250 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 251 out of 20000
# Dataframe Progress: Added 252 out of 20000
# Dataframe Progress: Added 253 out of 20000
# Dataframe Progress: Added 254 out of 20000
# Dataframe Progress: Added 255 out of 20000
# Dataframe Progress: Added 256 out of 20000
# Dataframe Progress: Added 257 out of 20000
# Dataframe Progress: Added 258 out of 20000
# Dataframe Progress: Added 259 out of 20000
# Dataframe Progress: Added 260 out of 20000
# Dataframe Progress: Added 261 out of 20000
# Dataframe Progress: Added 262 out of 20000
# Dataframe Progress: Added 263 out of 20000
# Dataframe Progress: Added 264 out of 20000
# Dataframe Progress: Added 265 out of 20000
# Dataframe Progress: Added 266 out of 20000
# Dataframe Progress: Added 267 out of 20000
# Dataframe Progress: Added 268 out of 20000
# Dataframe Progress: Added 269 out of 20000
# Dataframe Progress: Added 270 out of 20000
# Dataframe Progress: Added 271 out of 20000
# Dataframe Progress: Added 272 out of 20000
# Dataframe Progress: Added 273 out of 20000
# Dataframe Progress: Added 274 out of 20000
# Dataframe Progress: Added 275 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 276 out of 20000
# Dataframe Progress: Added 277 out of 20000
# Dataframe Progress: Added 278 out of 20000
# Dataframe Progress: Added 279 out of 20000
# Dataframe Progress: Added 280 out of 20000
# Dataframe Progress: Added 281 out of 20000
# Dataframe Progress: Added 282 out of 20000
# Dataframe Progress: Added 283 out of 20000
# Dataframe Progress: Added 284 out of 20000
# Dataframe Progress: Added 285 out of 20000
# Dataframe Progress: Added 286 out of 20000
# Dataframe Progress: Added 287 out of 20000
# Dataframe Progress: Added 288 out of 20000
# Dataframe Progress: Added 289 out of 20000
# Dataframe Progress: Added 290 out of 20000
# Dataframe Progress: Added 291 out of 20000
# Dataframe Progress: Added 292 out of 20000
# Dataframe Progress: Added 293 out of 20000
# Dataframe Progress: Added 294 out of 20000
# Dataframe Progress: Added 295 out of 20000
# Dataframe Progress: Added 296 out of 20000
# Dataframe Progress: Added 297 out of 20000
# Dataframe Progress: Added 298 out of 20000
# Dataframe Progress: Added 299 out of 20000
# Dataframe Progress: Added 300 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 301 out of 20000
# Dataframe Progress: Added 302 out of 20000
# Dataframe Progress: Added 303 out of 20000
# Dataframe Progress: Added 304 out of 20000
# Dataframe Progress: Added 305 out of 20000
# Dataframe Progress: Added 306 out of 20000
# Dataframe Progress: Added 307 out of 20000
# Dataframe Progress: Added 308 out of 20000
# Dataframe Progress: Added 309 out of 20000
# Dataframe Progress: Added 310 out of 20000
# Dataframe Progress: Added 311 out of 20000
# Dataframe Progress: Added 312 out of 20000
# Dataframe Progress: Added 313 out of 20000
# Dataframe Progress: Added 314 out of 20000
# Dataframe Progress: Added 315 out of 20000
# Dataframe Progress: Added 316 out of 20000
# Dataframe Progress: Added 317 out of 20000
# Dataframe Progress: Added 318 out of 20000
# Dataframe Progress: Added 319 out of 20000
# Dataframe Progress: Added 320 out of 20000
# Dataframe Progress: Added 321 out of 20000
# Dataframe Progress: Added 322 out of 20000
# Dataframe Progress: Added 323 out of 20000
# Dataframe Progress: Added 324 out of 20000
# Dataframe Progress: Added 325 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 326 out of 20000
# Dataframe Progress: Added 327 out of 20000
# Dataframe Progress: Added 328 out of 20000
# Dataframe Progress: Added 329 out of 20000
# Dataframe Progress: Added 330 out of 20000
# Dataframe Progress: Added 331 out of 20000
# Dataframe Progress: Added 332 out of 20000
# Dataframe Progress: Added 333 out of 20000
# Dataframe Progress: Added 334 out of 20000
# Dataframe Progress: Added 335 out of 20000
# Dataframe Progress: Added 336 out of 20000
# Dataframe Progress: Added 337 out of 20000
# Dataframe Progress: Added 338 out of 20000
# Dataframe Progress: Added 339 out of 20000
# Dataframe Progress: Added 340 out of 20000
# Dataframe Progress: Added 341 out of 20000
# Dataframe Progress: Added 342 out of 20000
# Dataframe Progress: Added 343 out of 20000
# Dataframe Progress: Added 344 out of 20000
# Dataframe Progress: Added 345 out of 20000
# Dataframe Progress: Added 346 out of 20000
# Dataframe Progress: Added 347 out of 20000
# Dataframe Progress: Added 348 out of 20000
# Dataframe Progress: Added 349 out of 20000
# Dataframe Progress: Added 350 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 351 out of 20000
# Dataframe Progress: Added 352 out of 20000
# Dataframe Progress: Added 353 out of 20000
# Dataframe Progress: Added 354 out of 20000
# Dataframe Progress: Added 355 out of 20000
# Dataframe Progress: Added 356 out of 20000
# Dataframe Progress: Added 357 out of 20000
# Dataframe Progress: Added 358 out of 20000
# Dataframe Progress: Added 359 out of 20000
# Dataframe Progress: Added 360 out of 20000
# Dataframe Progress: Added 361 out of 20000
# Dataframe Progress: Added 362 out of 20000
# Dataframe Progress: Added 363 out of 20000
# Dataframe Progress: Added 364 out of 20000
# Dataframe Progress: Added 365 out of 20000
# Dataframe Progress: Added 366 out of 20000
# Dataframe Progress: Added 367 out of 20000
# Dataframe Progress: Added 368 out of 20000
# Dataframe Progress: Added 369 out of 20000
# Dataframe Progress: Added 370 out of 20000
# Dataframe Progress: Added 371 out of 20000
# Dataframe Progress: Added 372 out of 20000
# Dataframe Progress: Added 373 out of 20000
# Dataframe Progress: Added 374 out of 20000
# Dataframe Progress: Added 375 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 376 out of 20000
# Dataframe Progress: Added 377 out of 20000
# Dataframe Progress: Added 378 out of 20000
# Dataframe Progress: Added 379 out of 20000
# Dataframe Progress: Added 380 out of 20000
# Dataframe Progress: Added 381 out of 20000
# Dataframe Progress: Added 382 out of 20000
# Dataframe Progress: Added 383 out of 20000
# Dataframe Progress: Added 384 out of 20000
# Dataframe Progress: Added 385 out of 20000
# Dataframe Progress: Added 386 out of 20000
# Dataframe Progress: Added 387 out of 20000
# Dataframe Progress: Added 388 out of 20000
# Dataframe Progress: Added 389 out of 20000
# Dataframe Progress: Added 390 out of 20000
# Dataframe Progress: Added 391 out of 20000
# Dataframe Progress: Added 392 out of 20000
# Dataframe Progress: Added 393 out of 20000
# Dataframe Progress: Added 394 out of 20000
# Dataframe Progress: Added 395 out of 20000
# Dataframe Progress: Added 396 out of 20000
# Dataframe Progress: Added 397 out of 20000
# Dataframe Progress: Added 398 out of 20000
# Dataframe Progress: Added 399 out of 20000
# Dataframe Progress: Added 400 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 401 out of 20000
# Dataframe Progress: Added 402 out of 20000
# Dataframe Progress: Added 403 out of 20000
# Dataframe Progress: Added 404 out of 20000
# Dataframe Progress: Added 405 out of 20000
# Dataframe Progress: Added 406 out of 20000
# Dataframe Progress: Added 407 out of 20000
# Dataframe Progress: Added 408 out of 20000
# Dataframe Progress: Added 409 out of 20000
# Dataframe Progress: Added 410 out of 20000
# Dataframe Progress: Added 411 out of 20000
# Dataframe Progress: Added 412 out of 20000
# Dataframe Progress: Added 413 out of 20000
# Dataframe Progress: Added 414 out of 20000
# Dataframe Progress: Added 415 out of 20000
# Dataframe Progress: Added 416 out of 20000
# Dataframe Progress: Added 417 out of 20000
# Dataframe Progress: Added 418 out of 20000
# Dataframe Progress: Added 419 out of 20000
# Dataframe Progress: Added 420 out of 20000
# Dataframe Progress: Added 421 out of 20000
# Dataframe Progress: Added 422 out of 20000
# Dataframe Progress: Added 423 out of 20000
# Dataframe Progress: Added 424 out of 20000
# Dataframe Progress: Added 425 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 426 out of 20000
# Dataframe Progress: Added 427 out of 20000
# Dataframe Progress: Added 428 out of 20000
# Dataframe Progress: Added 429 out of 20000
# Dataframe Progress: Added 430 out of 20000
# Dataframe Progress: Added 431 out of 20000
# Dataframe Progress: Added 432 out of 20000
# Dataframe Progress: Added 433 out of 20000
# Dataframe Progress: Added 434 out of 20000
# Dataframe Progress: Added 435 out of 20000
# Dataframe Progress: Added 436 out of 20000
# Dataframe Progress: Added 437 out of 20000
# Dataframe Progress: Added 438 out of 20000
# Dataframe Progress: Added 439 out of 20000
# Dataframe Progress: Added 440 out of 20000
# Dataframe Progress: Added 441 out of 20000
# Dataframe Progress: Added 442 out of 20000
# Dataframe Progress: Added 443 out of 20000
# Dataframe Progress: Added 444 out of 20000
# Dataframe Progress: Added 445 out of 20000
# Dataframe Progress: Added 446 out of 20000
# Dataframe Progress: Added 447 out of 20000
# Dataframe Progress: Added 448 out of 20000
# Dataframe Progress: Added 449 out of 20000
# Dataframe Progress: Added 450 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 451 out of 20000
# Dataframe Progress: Added 452 out of 20000
# Dataframe Progress: Added 453 out of 20000
# Dataframe Progress: Added 454 out of 20000
# Dataframe Progress: Added 455 out of 20000
# Dataframe Progress: Added 456 out of 20000
# Dataframe Progress: Added 457 out of 20000
# Dataframe Progress: Added 458 out of 20000
# Dataframe Progress: Added 459 out of 20000
# Dataframe Progress: Added 460 out of 20000
# Dataframe Progress: Added 461 out of 20000
# Dataframe Progress: Added 462 out of 20000
# Dataframe Progress: Added 463 out of 20000
# Dataframe Progress: Added 464 out of 20000
# Dataframe Progress: Added 465 out of 20000
# Dataframe Progress: Added 466 out of 20000
# Dataframe Progress: Added 467 out of 20000
# Dataframe Progress: Added 468 out of 20000
# Dataframe Progress: Added 469 out of 20000
# Dataframe Progress: Added 470 out of 20000
# Dataframe Progress: Added 471 out of 20000
# Dataframe Progress: Added 472 out of 20000
# Dataframe Progress: Added 473 out of 20000
# Dataframe Progress: Added 474 out of 20000
# Dataframe Progress: Added 475 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 476 out of 20000
# Dataframe Progress: Added 477 out of 20000
# Dataframe Progress: Added 478 out of 20000
# Dataframe Progress: Added 479 out of 20000
# Dataframe Progress: Added 480 out of 20000
# Dataframe Progress: Added 481 out of 20000
# Dataframe Progress: Added 482 out of 20000
# Dataframe Progress: Added 483 out of 20000
# Dataframe Progress: Added 484 out of 20000
# Dataframe Progress: Added 485 out of 20000
# Dataframe Progress: Added 486 out of 20000
# Dataframe Progress: Added 487 out of 20000
# Dataframe Progress: Added 488 out of 20000
# Dataframe Progress: Added 489 out of 20000
# Dataframe Progress: Added 490 out of 20000
# Dataframe Progress: Added 491 out of 20000
# Dataframe Progress: Added 492 out of 20000
# Dataframe Progress: Added 493 out of 20000
# Dataframe Progress: Added 494 out of 20000
# Dataframe Progress: Added 495 out of 20000
# Dataframe Progress: Added 496 out of 20000
# Dataframe Progress: Added 497 out of 20000
# Dataframe Progress: Added 498 out of 20000
# Dataframe Progress: Added 499 out of 20000
# Dataframe Progress: Added 500 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 501 out of 20000
# Dataframe Progress: Added 502 out of 20000
# Dataframe Progress: Added 503 out of 20000
# Dataframe Progress: Added 504 out of 20000
# Dataframe Progress: Added 505 out of 20000
# Dataframe Progress: Added 506 out of 20000
# Dataframe Progress: Added 507 out of 20000
# Dataframe Progress: Added 508 out of 20000
# Dataframe Progress: Added 509 out of 20000
# Dataframe Progress: Added 510 out of 20000
# Dataframe Progress: Added 511 out of 20000
# Dataframe Progress: Added 512 out of 20000
# Dataframe Progress: Added 513 out of 20000
# Dataframe Progress: Added 514 out of 20000
# Dataframe Progress: Added 515 out of 20000
# Dataframe Progress: Added 516 out of 20000
# Dataframe Progress: Added 517 out of 20000
# Dataframe Progress: Added 518 out of 20000
# Dataframe Progress: Added 519 out of 20000
# Dataframe Progress: Added 520 out of 20000
# Dataframe Progress: Added 521 out of 20000
# Dataframe Progress: Added 522 out of 20000
# Dataframe Progress: Added 523 out of 20000
# Dataframe Progress: Added 524 out of 20000
# Dataframe Progress: Added 525 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 526 out of 20000
# Dataframe Progress: Added 527 out of 20000
# Dataframe Progress: Added 528 out of 20000
# Dataframe Progress: Added 529 out of 20000
# Dataframe Progress: Added 530 out of 20000
# Dataframe Progress: Added 531 out of 20000
# Dataframe Progress: Added 532 out of 20000
# Dataframe Progress: Added 533 out of 20000
# Dataframe Progress: Added 534 out of 20000
# Dataframe Progress: Added 535 out of 20000
# Dataframe Progress: Added 536 out of 20000
# Dataframe Progress: Added 537 out of 20000
# Dataframe Progress: Added 538 out of 20000
# Dataframe Progress: Added 539 out of 20000
# Dataframe Progress: Added 540 out of 20000
# Dataframe Progress: Added 541 out of 20000
# Dataframe Progress: Added 542 out of 20000
# Dataframe Progress: Added 543 out of 20000
# Dataframe Progress: Added 544 out of 20000
# Dataframe Progress: Added 545 out of 20000
# Dataframe Progress: Added 546 out of 20000
# Dataframe Progress: Added 547 out of 20000
# Dataframe Progress: Added 548 out of 20000
# Dataframe Progress: Added 549 out of 20000
# Dataframe Progress: Added 550 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 551 out of 20000
# Dataframe Progress: Added 552 out of 20000
# Dataframe Progress: Added 553 out of 20000
# Dataframe Progress: Added 554 out of 20000
# Dataframe Progress: Added 555 out of 20000
# Dataframe Progress: Added 556 out of 20000
# Dataframe Progress: Added 557 out of 20000
# Dataframe Progress: Added 558 out of 20000
# Dataframe Progress: Added 559 out of 20000
# Dataframe Progress: Added 560 out of 20000
# Dataframe Progress: Added 561 out of 20000
# Dataframe Progress: Added 562 out of 20000
# Dataframe Progress: Added 563 out of 20000
# Dataframe Progress: Added 564 out of 20000
# Dataframe Progress: Added 565 out of 20000
# Dataframe Progress: Added 566 out of 20000
# Dataframe Progress: Added 567 out of 20000
# Dataframe Progress: Added 568 out of 20000
# Dataframe Progress: Added 569 out of 20000
# Dataframe Progress: Added 570 out of 20000
# Dataframe Progress: Added 571 out of 20000
# Dataframe Progress: Added 572 out of 20000
# Dataframe Progress: Added 573 out of 20000
# Dataframe Progress: Added 574 out of 20000
# Dataframe Progress: Added 575 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 576 out of 20000
# Dataframe Progress: Added 577 out of 20000
# Dataframe Progress: Added 578 out of 20000
# Dataframe Progress: Added 579 out of 20000
# Dataframe Progress: Added 580 out of 20000
# Dataframe Progress: Added 581 out of 20000
# Dataframe Progress: Added 582 out of 20000
# Dataframe Progress: Added 583 out of 20000
# Dataframe Progress: Added 584 out of 20000
# Dataframe Progress: Added 585 out of 20000
# Dataframe Progress: Added 586 out of 20000
# Dataframe Progress: Added 587 out of 20000
# Dataframe Progress: Added 588 out of 20000
# Dataframe Progress: Added 589 out of 20000
# Dataframe Progress: Added 590 out of 20000
# Dataframe Progress: Added 591 out of 20000
# Dataframe Progress: Added 592 out of 20000
# Dataframe Progress: Added 593 out of 20000
# Dataframe Progress: Added 594 out of 20000
# Dataframe Progress: Added 595 out of 20000
# Dataframe Progress: Added 596 out of 20000
# Dataframe Progress: Added 597 out of 20000
# Dataframe Progress: Added 598 out of 20000
# Dataframe Progress: Added 599 out of 20000
# Dataframe Progress: Added 600 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 601 out of 20000
# Dataframe Progress: Added 602 out of 20000
# Dataframe Progress: Added 603 out of 20000
# Dataframe Progress: Added 604 out of 20000
# Dataframe Progress: Added 605 out of 20000
# Dataframe Progress: Added 606 out of 20000
# Dataframe Progress: Added 607 out of 20000
# Dataframe Progress: Added 608 out of 20000
# Dataframe Progress: Added 609 out of 20000
# Dataframe Progress: Added 610 out of 20000
# Dataframe Progress: Added 611 out of 20000
# Dataframe Progress: Added 612 out of 20000
# Dataframe Progress: Added 613 out of 20000
# Dataframe Progress: Added 614 out of 20000
# Dataframe Progress: Added 615 out of 20000
# Dataframe Progress: Added 616 out of 20000
# Dataframe Progress: Added 617 out of 20000
# Dataframe Progress: Added 618 out of 20000
# Dataframe Progress: Added 619 out of 20000
# Dataframe Progress: Added 620 out of 20000
# Dataframe Progress: Added 621 out of 20000
# Dataframe Progress: Added 622 out of 20000
# Dataframe Progress: Added 623 out of 20000
# Dataframe Progress: Added 624 out of 20000
# Dataframe Progress: Added 625 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 626 out of 20000
# Dataframe Progress: Added 627 out of 20000
# Dataframe Progress: Added 628 out of 20000
# Dataframe Progress: Added 629 out of 20000
# Dataframe Progress: Added 630 out of 20000
# Dataframe Progress: Added 631 out of 20000
# Dataframe Progress: Added 632 out of 20000
# Dataframe Progress: Added 633 out of 20000
# Dataframe Progress: Added 634 out of 20000
# Dataframe Progress: Added 635 out of 20000
# Dataframe Progress: Added 636 out of 20000
# Dataframe Progress: Added 637 out of 20000
# Dataframe Progress: Added 638 out of 20000
# Dataframe Progress: Added 639 out of 20000
# Dataframe Progress: Added 640 out of 20000
# Dataframe Progress: Added 641 out of 20000
# Dataframe Progress: Added 642 out of 20000
# Dataframe Progress: Added 643 out of 20000
# Dataframe Progress: Added 644 out of 20000
# Dataframe Progress: Added 645 out of 20000
# Dataframe Progress: Added 646 out of 20000
# Dataframe Progress: Added 647 out of 20000
# Dataframe Progress: Added 648 out of 20000
# Dataframe Progress: Added 649 out of 20000
# Dataframe Progress: Added 650 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 651 out of 20000
# Dataframe Progress: Added 652 out of 20000
# Dataframe Progress: Added 653 out of 20000
# Dataframe Progress: Added 654 out of 20000
# Dataframe Progress: Added 655 out of 20000
# Dataframe Progress: Added 656 out of 20000
# Dataframe Progress: Added 657 out of 20000
# Dataframe Progress: Added 658 out of 20000
# Dataframe Progress: Added 659 out of 20000
# Dataframe Progress: Added 660 out of 20000
# Dataframe Progress: Added 661 out of 20000
# Dataframe Progress: Added 662 out of 20000
# Dataframe Progress: Added 663 out of 20000
# Dataframe Progress: Added 664 out of 20000
# Dataframe Progress: Added 665 out of 20000
# Dataframe Progress: Added 666 out of 20000
# Dataframe Progress: Added 667 out of 20000
# Dataframe Progress: Added 668 out of 20000
# Dataframe Progress: Added 669 out of 20000
# Dataframe Progress: Added 670 out of 20000
# Dataframe Progress: Added 671 out of 20000
# Dataframe Progress: Added 672 out of 20000
# Dataframe Progress: Added 673 out of 20000
# Dataframe Progress: Added 674 out of 20000
# Dataframe Progress: Added 675 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 676 out of 20000
# Dataframe Progress: Added 677 out of 20000
# Dataframe Progress: Added 678 out of 20000
# Dataframe Progress: Added 679 out of 20000
# Dataframe Progress: Added 680 out of 20000
# Dataframe Progress: Added 681 out of 20000
# Dataframe Progress: Added 682 out of 20000
# Dataframe Progress: Added 683 out of 20000
# Dataframe Progress: Added 684 out of 20000
# Dataframe Progress: Added 685 out of 20000
# Dataframe Progress: Added 686 out of 20000
# Dataframe Progress: Added 687 out of 20000
# Dataframe Progress: Added 688 out of 20000
# Dataframe Progress: Added 689 out of 20000
# Dataframe Progress: Added 690 out of 20000
# Dataframe Progress: Added 691 out of 20000
# Dataframe Progress: Added 692 out of 20000
# Dataframe Progress: Added 693 out of 20000
# Dataframe Progress: Added 694 out of 20000
# Dataframe Progress: Added 695 out of 20000
# Dataframe Progress: Added 696 out of 20000
# Dataframe Progress: Added 697 out of 20000
# Dataframe Progress: Added 698 out of 20000
# Dataframe Progress: Added 699 out of 20000
# Dataframe Progress: Added 700 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 701 out of 20000
# Dataframe Progress: Added 702 out of 20000
# Dataframe Progress: Added 703 out of 20000
# Dataframe Progress: Added 704 out of 20000
# Dataframe Progress: Added 705 out of 20000
# Dataframe Progress: Added 706 out of 20000
# Dataframe Progress: Added 707 out of 20000
# Dataframe Progress: Added 708 out of 20000
# Dataframe Progress: Added 709 out of 20000
# Dataframe Progress: Added 710 out of 20000
# Dataframe Progress: Added 711 out of 20000
# Dataframe Progress: Added 712 out of 20000
# Dataframe Progress: Added 713 out of 20000
# Dataframe Progress: Added 714 out of 20000
# Dataframe Progress: Added 715 out of 20000
# Dataframe Progress: Added 716 out of 20000
# Dataframe Progress: Added 717 out of 20000
# Dataframe Progress: Added 718 out of 20000
# Dataframe Progress: Added 719 out of 20000
# Dataframe Progress: Added 720 out of 20000
# Dataframe Progress: Added 721 out of 20000
# Dataframe Progress: Added 722 out of 20000
# Dataframe Progress: Added 723 out of 20000
# Dataframe Progress: Added 724 out of 20000
# Dataframe Progress: Added 725 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 726 out of 20000
# Dataframe Progress: Added 727 out of 20000
# Dataframe Progress: Added 728 out of 20000
# Dataframe Progress: Added 729 out of 20000
# Dataframe Progress: Added 730 out of 20000
# Dataframe Progress: Added 731 out of 20000
# Dataframe Progress: Added 732 out of 20000
# Dataframe Progress: Added 733 out of 20000
# Dataframe Progress: Added 734 out of 20000
# Dataframe Progress: Added 735 out of 20000
# Dataframe Progress: Added 736 out of 20000
# Dataframe Progress: Added 737 out of 20000
# Dataframe Progress: Added 738 out of 20000
# Dataframe Progress: Added 739 out of 20000
# Dataframe Progress: Added 740 out of 20000
# Dataframe Progress: Added 741 out of 20000
# Dataframe Progress: Added 742 out of 20000
# Dataframe Progress: Added 743 out of 20000
# Dataframe Progress: Added 744 out of 20000
# Dataframe Progress: Added 745 out of 20000
# Dataframe Progress: Added 746 out of 20000
# Dataframe Progress: Added 747 out of 20000
# Dataframe Progress: Added 748 out of 20000
# Dataframe Progress: Added 749 out of 20000
# Dataframe Progress: Added 750 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 751 out of 20000
# Dataframe Progress: Added 752 out of 20000
# Dataframe Progress: Added 753 out of 20000
# Dataframe Progress: Added 754 out of 20000
# Dataframe Progress: Added 755 out of 20000
# Dataframe Progress: Added 756 out of 20000
# Dataframe Progress: Added 757 out of 20000
# Dataframe Progress: Added 758 out of 20000
# Dataframe Progress: Added 759 out of 20000
# Dataframe Progress: Added 760 out of 20000
# Dataframe Progress: Added 761 out of 20000
# Dataframe Progress: Added 762 out of 20000
# Dataframe Progress: Added 763 out of 20000
# Dataframe Progress: Added 764 out of 20000
# Dataframe Progress: Added 765 out of 20000
# Dataframe Progress: Added 766 out of 20000
# Dataframe Progress: Added 767 out of 20000
# Dataframe Progress: Added 768 out of 20000
# Dataframe Progress: Added 769 out of 20000
# Dataframe Progress: Added 770 out of 20000
# Dataframe Progress: Added 771 out of 20000
# Dataframe Progress: Added 772 out of 20000
# Dataframe Progress: Added 773 out of 20000
# Dataframe Progress: Added 774 out of 20000
# Dataframe Progress: Added 775 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 776 out of 20000
# Dataframe Progress: Added 777 out of 20000
# Dataframe Progress: Added 778 out of 20000
# Dataframe Progress: Added 779 out of 20000
# Dataframe Progress: Added 780 out of 20000
# Dataframe Progress: Added 781 out of 20000
# Dataframe Progress: Added 782 out of 20000
# Dataframe Progress: Added 783 out of 20000
# Dataframe Progress: Added 784 out of 20000
# Dataframe Progress: Added 785 out of 20000
# Dataframe Progress: Added 786 out of 20000
# Dataframe Progress: Added 787 out of 20000
# Dataframe Progress: Added 788 out of 20000
# Dataframe Progress: Added 789 out of 20000
# Dataframe Progress: Added 790 out of 20000
# Dataframe Progress: Added 791 out of 20000
# Dataframe Progress: Added 792 out of 20000
# Dataframe Progress: Added 793 out of 20000
# Dataframe Progress: Added 794 out of 20000
# Dataframe Progress: Added 795 out of 20000
# Dataframe Progress: Added 796 out of 20000
# Dataframe Progress: Added 797 out of 20000
# Dataframe Progress: Added 798 out of 20000
# Dataframe Progress: Added 799 out of 20000
# Dataframe Progress: Added 800 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 801 out of 20000
# Dataframe Progress: Added 802 out of 20000
# Dataframe Progress: Added 803 out of 20000
# Dataframe Progress: Added 804 out of 20000
# Dataframe Progress: Added 805 out of 20000
# Dataframe Progress: Added 806 out of 20000
# Dataframe Progress: Added 807 out of 20000
# Dataframe Progress: Added 808 out of 20000
# Dataframe Progress: Added 809 out of 20000
# Dataframe Progress: Added 810 out of 20000
# Dataframe Progress: Added 811 out of 20000
# Dataframe Progress: Added 812 out of 20000
# Dataframe Progress: Added 813 out of 20000
# Dataframe Progress: Added 814 out of 20000
# Dataframe Progress: Added 815 out of 20000
# Dataframe Progress: Added 816 out of 20000
# Dataframe Progress: Added 817 out of 20000
# Dataframe Progress: Added 818 out of 20000
# Dataframe Progress: Added 819 out of 20000
# Dataframe Progress: Added 820 out of 20000
# Dataframe Progress: Added 821 out of 20000
# Dataframe Progress: Added 822 out of 20000
# Dataframe Progress: Added 823 out of 20000
# Dataframe Progress: Added 824 out of 20000
# Dataframe Progress: Added 825 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 826 out of 20000
# Dataframe Progress: Added 827 out of 20000
# Dataframe Progress: Added 828 out of 20000
# Dataframe Progress: Added 829 out of 20000
# Dataframe Progress: Added 830 out of 20000
# Dataframe Progress: Added 831 out of 20000
# Dataframe Progress: Added 832 out of 20000
# Dataframe Progress: Added 833 out of 20000
# Dataframe Progress: Added 834 out of 20000
# Dataframe Progress: Added 835 out of 20000
# Dataframe Progress: Added 836 out of 20000
# Dataframe Progress: Added 837 out of 20000
# Dataframe Progress: Added 838 out of 20000
# Dataframe Progress: Added 839 out of 20000
# Dataframe Progress: Added 840 out of 20000
# Dataframe Progress: Added 841 out of 20000
# Dataframe Progress: Added 842 out of 20000
# Dataframe Progress: Added 843 out of 20000
# Dataframe Progress: Added 844 out of 20000
# Dataframe Progress: Added 845 out of 20000
# Dataframe Progress: Added 846 out of 20000
# Dataframe Progress: Added 847 out of 20000
# Dataframe Progress: Added 848 out of 20000
# Dataframe Progress: Added 849 out of 20000
# Dataframe Progress: Added 850 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 851 out of 20000
# Dataframe Progress: Added 852 out of 20000
# Dataframe Progress: Added 853 out of 20000
# Dataframe Progress: Added 854 out of 20000
# Dataframe Progress: Added 855 out of 20000
# Dataframe Progress: Added 856 out of 20000
# Dataframe Progress: Added 857 out of 20000
# Dataframe Progress: Added 858 out of 20000
# Dataframe Progress: Added 859 out of 20000
# Dataframe Progress: Added 860 out of 20000
# Dataframe Progress: Added 861 out of 20000
# Dataframe Progress: Added 862 out of 20000
# Dataframe Progress: Added 863 out of 20000
# Dataframe Progress: Added 864 out of 20000
# Dataframe Progress: Added 865 out of 20000
# Dataframe Progress: Added 866 out of 20000
# Dataframe Progress: Added 867 out of 20000
# Dataframe Progress: Added 868 out of 20000
# Dataframe Progress: Added 869 out of 20000
# Dataframe Progress: Added 870 out of 20000
# Dataframe Progress: Added 871 out of 20000
# Dataframe Progress: Added 872 out of 20000
# Dataframe Progress: Added 873 out of 20000
# Dataframe Progress: Added 874 out of 20000
# Dataframe Progress: Added 875 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 876 out of 20000
# Dataframe Progress: Added 877 out of 20000
# Dataframe Progress: Added 878 out of 20000
# Dataframe Progress: Added 879 out of 20000
# Dataframe Progress: Added 880 out of 20000
# Dataframe Progress: Added 881 out of 20000
# Dataframe Progress: Added 882 out of 20000
# Dataframe Progress: Added 883 out of 20000
# Dataframe Progress: Added 884 out of 20000
# Dataframe Progress: Added 885 out of 20000
# Dataframe Progress: Added 886 out of 20000
# Dataframe Progress: Added 887 out of 20000
# Dataframe Progress: Added 888 out of 20000
# Dataframe Progress: Added 889 out of 20000
# Dataframe Progress: Added 890 out of 20000
# Dataframe Progress: Added 891 out of 20000
# Dataframe Progress: Added 892 out of 20000
# Dataframe Progress: Added 893 out of 20000
# Dataframe Progress: Added 894 out of 20000
# Dataframe Progress: Added 895 out of 20000
# Dataframe Progress: Added 896 out of 20000
# Dataframe Progress: Added 897 out of 20000
# Dataframe Progress: Added 898 out of 20000
# Dataframe Progress: Added 899 out of 20000
# Dataframe Progress: Added 900 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 901 out of 20000
# Dataframe Progress: Added 902 out of 20000
# Dataframe Progress: Added 903 out of 20000
# Dataframe Progress: Added 904 out of 20000
# Dataframe Progress: Added 905 out of 20000
# Dataframe Progress: Added 906 out of 20000
# Dataframe Progress: Added 907 out of 20000
# Dataframe Progress: Added 908 out of 20000
# Dataframe Progress: Added 909 out of 20000
# Dataframe Progress: Added 910 out of 20000
# Dataframe Progress: Added 911 out of 20000
# Dataframe Progress: Added 912 out of 20000
# Dataframe Progress: Added 913 out of 20000
# Dataframe Progress: Added 914 out of 20000
# Dataframe Progress: Added 915 out of 20000
# Dataframe Progress: Added 916 out of 20000
# Dataframe Progress: Added 917 out of 20000
# Dataframe Progress: Added 918 out of 20000
# Dataframe Progress: Added 919 out of 20000
# Dataframe Progress: Added 920 out of 20000
# Dataframe Progress: Added 921 out of 20000
# Dataframe Progress: Added 922 out of 20000
# Dataframe Progress: Added 923 out of 20000
# Dataframe Progress: Added 924 out of 20000
# Dataframe Progress: Added 925 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 926 out of 20000
# Dataframe Progress: Added 927 out of 20000
# Dataframe Progress: Added 928 out of 20000
# Dataframe Progress: Added 929 out of 20000
# Dataframe Progress: Added 930 out of 20000
# Dataframe Progress: Added 931 out of 20000
# Dataframe Progress: Added 932 out of 20000
# Dataframe Progress: Added 933 out of 20000
# Dataframe Progress: Added 934 out of 20000
# Dataframe Progress: Added 935 out of 20000
# Dataframe Progress: Added 936 out of 20000
# Dataframe Progress: Added 937 out of 20000
# Dataframe Progress: Added 938 out of 20000
# Dataframe Progress: Added 939 out of 20000
# Dataframe Progress: Added 940 out of 20000
# Dataframe Progress: Added 941 out of 20000
# Dataframe Progress: Added 942 out of 20000
# Dataframe Progress: Added 943 out of 20000
# Dataframe Progress: Added 944 out of 20000
# Dataframe Progress: Added 945 out of 20000
# Dataframe Progress: Added 946 out of 20000
# Dataframe Progress: Added 947 out of 20000
# Dataframe Progress: Added 948 out of 20000
# Dataframe Progress: Added 949 out of 20000
# Dataframe Progress: Added 950 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 951 out of 20000
# Dataframe Progress: Added 952 out of 20000
# Dataframe Progress: Added 953 out of 20000
# Dataframe Progress: Added 954 out of 20000
# Dataframe Progress: Added 955 out of 20000
# Dataframe Progress: Added 956 out of 20000
# Dataframe Progress: Added 957 out of 20000
# Dataframe Progress: Added 958 out of 20000
# Dataframe Progress: Added 959 out of 20000
# Dataframe Progress: Added 960 out of 20000
# Dataframe Progress: Added 961 out of 20000
# Dataframe Progress: Added 962 out of 20000
# Dataframe Progress: Added 963 out of 20000
# Dataframe Progress: Added 964 out of 20000
# Dataframe Progress: Added 965 out of 20000
# Dataframe Progress: Added 966 out of 20000
# Dataframe Progress: Added 967 out of 20000
# Dataframe Progress: Added 968 out of 20000
# Dataframe Progress: Added 969 out of 20000
# Dataframe Progress: Added 970 out of 20000
# Dataframe Progress: Added 971 out of 20000
# Dataframe Progress: Added 972 out of 20000
# Dataframe Progress: Added 973 out of 20000
# Dataframe Progress: Added 974 out of 20000
# Dataframe Progress: Added 975 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 976 out of 20000
# Dataframe Progress: Added 977 out of 20000
# Dataframe Progress: Added 978 out of 20000
# Dataframe Progress: Added 979 out of 20000
# Dataframe Progress: Added 980 out of 20000
# Dataframe Progress: Added 981 out of 20000
# Dataframe Progress: Added 982 out of 20000
# Dataframe Progress: Added 983 out of 20000
# Dataframe Progress: Added 984 out of 20000
# Dataframe Progress: Added 985 out of 20000
# Dataframe Progress: Added 986 out of 20000
# Dataframe Progress: Added 987 out of 20000
# Dataframe Progress: Added 988 out of 20000
# Dataframe Progress: Added 989 out of 20000
# Dataframe Progress: Added 990 out of 20000
# Dataframe Progress: Added 991 out of 20000
# Dataframe Progress: Added 992 out of 20000
# Dataframe Progress: Added 993 out of 20000
# Dataframe Progress: Added 994 out of 20000
# Dataframe Progress: Added 995 out of 20000
# Dataframe Progress: Added 996 out of 20000
# Dataframe Progress: Added 997 out of 20000
# Dataframe Progress: Added 998 out of 20000
# Dataframe Progress: Added 999 out of 20000
# Dataframe Progress: Added 1000 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 1001 out of 20000
# Dataframe Progress: Added 1002 out of 20000
# Dataframe Progress: Added 1003 out of 20000
# Dataframe Progress: Added 1004 out of 20000
# Dataframe Progress: Added 1005 out of 20000
# Dataframe Progress: Added 1006 out of 20000
# Dataframe Progress: Added 1007 out of 20000
# Dataframe Progress: Added 1008 out of 20000
# Dataframe Progress: Added 1009 out of 20000
# Dataframe Progress: Added 1010 out of 20000
# Dataframe Progress: Added 1011 out of 20000
# Dataframe Progress: Added 1012 out of 20000
# Dataframe Progress: Added 1013 out of 20000
# Dataframe Progress: Added 1014 out of 20000
# Dataframe Progress: Added 1015 out of 20000
# Dataframe Progress: Added 1016 out of 20000
# Dataframe Progress: Added 1017 out of 20000
# Dataframe Progress: Added 1018 out of 20000
# Dataframe Progress: Added 1019 out of 20000
# Dataframe Progress: Added 1020 out of 20000
# Dataframe Progress: Added 1021 out of 20000
# Dataframe Progress: Added 1022 out of 20000
# Dataframe Progress: Added 1023 out of 20000
# Dataframe Progress: Added 1024 out of 20000
# Dataframe Progress: Added 1025 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 1026 out of 20000
# Dataframe Progress: Added 1027 out of 20000
# Dataframe Progress: Added 1028 out of 20000
# Dataframe Progress: Added 1029 out of 20000
# Dataframe Progress: Added 1030 out of 20000
# Dataframe Progress: Added 1031 out of 20000
# Dataframe Progress: Added 1032 out of 20000
# Dataframe Progress: Added 1033 out of 20000
# Dataframe Progress: Added 1034 out of 20000
# Dataframe Progress: Added 1035 out of 20000
# Dataframe Progress: Added 1036 out of 20000
# Dataframe Progress: Added 1037 out of 20000
# Dataframe Progress: Added 1038 out of 20000
# Dataframe Progress: Added 1039 out of 20000
# Dataframe Progress: Added 1040 out of 20000
# Dataframe Progress: Added 1041 out of 20000
# Dataframe Progress: Added 1042 out of 20000
# Dataframe Progress: Added 1043 out of 20000
# Dataframe Progress: Added 1044 out of 20000
# Dataframe Progress: Added 1045 out of 20000
# Dataframe Progress: Added 1046 out of 20000
# Dataframe Progress: Added 1047 out of 20000
# Dataframe Progress: Added 1048 out of 20000
# Dataframe Progress: Added 1049 out of 20000
# Dataframe Progress: Added 1050 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 1051 out of 20000
# Dataframe Progress: Added 1052 out of 20000
# Dataframe Progress: Added 1053 out of 20000
# Dataframe Progress: Added 1054 out of 20000
# Dataframe Progress: Added 1055 out of 20000
# Dataframe Progress: Added 1056 out of 20000
# Dataframe Progress: Added 1057 out of 20000
# Dataframe Progress: Added 1058 out of 20000
# Dataframe Progress: Added 1059 out of 20000
# Dataframe Progress: Added 1060 out of 20000
# Dataframe Progress: Added 1061 out of 20000
# Dataframe Progress: Added 1062 out of 20000
# Dataframe Progress: Added 1063 out of 20000
# Dataframe Progress: Added 1064 out of 20000
# Dataframe Progress: Added 1065 out of 20000
# Dataframe Progress: Added 1066 out of 20000
# Dataframe Progress: Added 1067 out of 20000
# Dataframe Progress: Added 1068 out of 20000
# Dataframe Progress: Added 1069 out of 20000
# Dataframe Progress: Added 1070 out of 20000
# Dataframe Progress: Added 1071 out of 20000
# Dataframe Progress: Added 1072 out of 20000
# Dataframe Progress: Added 1073 out of 20000
# Dataframe Progress: Added 1074 out of 20000
# Dataframe Progress: Added 1075 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 1076 out of 20000
# Dataframe Progress: Added 1077 out of 20000
# Dataframe Progress: Added 1078 out of 20000
# Dataframe Progress: Added 1079 out of 20000
# Dataframe Progress: Added 1080 out of 20000
# Dataframe Progress: Added 1081 out of 20000
# Dataframe Progress: Added 1082 out of 20000
# ...
# Dataframe Progress: Added 19630 out of 20000
# Dataframe Progress: Added 19631 out of 20000
# Dataframe Progress: Added 19632 out of 20000
# Dataframe Progress: Added 19633 out of 20000
# Dataframe Progress: Added 19634 out of 20000
# Dataframe Progress: Added 19635 out of 20000
# Dataframe Progress: Added 19636 out of 20000
# Dataframe Progress: Added 19637 out of 20000
# Dataframe Progress: Added 19638 out of 20000
# Dataframe Progress: Added 19639 out of 20000
# Dataframe Progress: Added 19640 out of 20000
# Dataframe Progress: Added 19641 out of 20000
# Dataframe Progress: Added 19642 out of 20000
# Dataframe Progress: Added 19643 out of 20000
# Dataframe Progress: Added 19644 out of 20000
# Dataframe Progress: Added 19645 out of 20000
# Dataframe Progress: Added 19646 out of 20000
# Dataframe Progress: Added 19647 out of 20000
# Dataframe Progress: Added 19648 out of 20000
# Dataframe Progress: Added 19649 out of 20000
# Dataframe Progress: Added 19650 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 19651 out of 20000
# Dataframe Progress: Added 19652 out of 20000
# Dataframe Progress: Added 19653 out of 20000
# Dataframe Progress: Added 19654 out of 20000
# Dataframe Progress: Added 19655 out of 20000
# Dataframe Progress: Added 19656 out of 20000
# Dataframe Progress: Added 19657 out of 20000
# Dataframe Progress: Added 19658 out of 20000
# Dataframe Progress: Added 19659 out of 20000
# Dataframe Progress: Added 19660 out of 20000
# Dataframe Progress: Added 19661 out of 20000
# Dataframe Progress: Added 19662 out of 20000
# Dataframe Progress: Added 19663 out of 20000
# Dataframe Progress: Added 19664 out of 20000
# Dataframe Progress: Added 19665 out of 20000
# Dataframe Progress: Added 19666 out of 20000
# Dataframe Progress: Added 19667 out of 20000
# Dataframe Progress: Added 19668 out of 20000
# Dataframe Progress: Added 19669 out of 20000
# Dataframe Progress: Added 19670 out of 20000
# Dataframe Progress: Added 19671 out of 20000
# Dataframe Progress: Added 19672 out of 20000
# Dataframe Progress: Added 19673 out of 20000
# Dataframe Progress: Added 19674 out of 20000
# Dataframe Progress: Added 19675 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 19676 out of 20000
# Dataframe Progress: Added 19677 out of 20000
# Dataframe Progress: Added 19678 out of 20000
# Dataframe Progress: Added 19679 out of 20000
# Dataframe Progress: Added 19680 out of 20000
# Dataframe Progress: Added 19681 out of 20000
# Dataframe Progress: Added 19682 out of 20000
# Dataframe Progress: Added 19683 out of 20000
# Dataframe Progress: Added 19684 out of 20000
# Dataframe Progress: Added 19685 out of 20000
# Dataframe Progress: Added 19686 out of 20000
# Dataframe Progress: Added 19687 out of 20000
# Dataframe Progress: Added 19688 out of 20000
# Dataframe Progress: Added 19689 out of 20000
# Dataframe Progress: Added 19690 out of 20000
# Dataframe Progress: Added 19691 out of 20000
# Dataframe Progress: Added 19692 out of 20000
# Dataframe Progress: Added 19693 out of 20000
# Dataframe Progress: Added 19694 out of 20000
# Dataframe Progress: Added 19695 out of 20000
# Dataframe Progress: Added 19696 out of 20000
# Dataframe Progress: Added 19697 out of 20000
# Dataframe Progress: Added 19698 out of 20000
# Dataframe Progress: Added 19699 out of 20000
# Dataframe Progress: Added 19700 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 19701 out of 20000
# Dataframe Progress: Added 19702 out of 20000
# Dataframe Progress: Added 19703 out of 20000
# Dataframe Progress: Added 19704 out of 20000
# Dataframe Progress: Added 19705 out of 20000
# Dataframe Progress: Added 19706 out of 20000
# Dataframe Progress: Added 19707 out of 20000
# Dataframe Progress: Added 19708 out of 20000
# Dataframe Progress: Added 19709 out of 20000
# Dataframe Progress: Added 19710 out of 20000
# Dataframe Progress: Added 19711 out of 20000
# Dataframe Progress: Added 19712 out of 20000
# Dataframe Progress: Added 19713 out of 20000
# Dataframe Progress: Added 19714 out of 20000
# Dataframe Progress: Added 19715 out of 20000
# Dataframe Progress: Added 19742 out of 20000
# Dataframe Progress: Added 19743 out of 20000
# Dataframe Progress: Added 19744 out of 20000
# Dataframe Progress: Added 19745 out of 20000
# Dataframe Progress: Added 19746 out of 20000
# Dataframe Progress: Added 19747 out of 20000
# Dataframe Progress: Added 19748 out of 20000
# Dataframe Progress: Added 19749 out of 20000
# Dataframe Progress: Added 19750 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 19751 out of 20000
# Dataframe Progress: Added 19752 out of 20000
# Dataframe Progress: Added 19753 out of 20000
# Dataframe Progress: Added 19754 out of 20000
# Dataframe Progress: Added 19755 out of 20000
# Dataframe Progress: Added 19756 out of 20000
# Dataframe Progress: Added 19757 out of 20000
# Dataframe Progress: Added 19758 out of 20000
# Dataframe Progress: Added 19759 out of 20000
# Dataframe Progress: Added 19760 out of 20000
# Dataframe Progress: Added 19761 out of 20000
# Dataframe Progress: Added 19762 out of 20000
# Dataframe Progress: Added 19763 out of 20000
# Dataframe Progress: Added 19764 out of 20000
# Dataframe Progress: Added 19765 out of 20000
# Dataframe Progress: Added 19766 out of 20000
# Dataframe Progress: Added 19767 out of 20000
# Dataframe Progress: Added 19768 out of 20000
# Dataframe Progress: Added 19769 out of 20000
# Dataframe Progress: Added 19770 out of 20000
# Dataframe Progress: Added 19771 out of 20000
# Dataframe Progress: Added 19772 out of 20000
# Dataframe Progress: Added 19773 out of 20000
# Dataframe Progress: Added 19774 out of 20000
# Dataframe Progress: Added 19775 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 19776 out of 20000
# Dataframe Progress: Added 19777 out of 20000
# Dataframe Progress: Added 19778 out of 20000
# Dataframe Progress: Added 19779 out of 20000
# Dataframe Progress: Added 19780 out of 20000
# Dataframe Progress: Added 19781 out of 20000
# Dataframe Progress: Added 19782 out of 20000
# Dataframe Progress: Added 19783 out of 20000
# Dataframe Progress: Added 19784 out of 20000
# Dataframe Progress: Added 19785 out of 20000
# Dataframe Progress: Added 19786 out of 20000
# Dataframe Progress: Added 19787 out of 20000
# Dataframe Progress: Added 19788 out of 20000
# Dataframe Progress: Added 19789 out of 20000
# Dataframe Progress: Added 19790 out of 20000
# Dataframe Progress: Added 19791 out of 20000
# Dataframe Progress: Added 19792 out of 20000
# Dataframe Progress: Added 19793 out of 20000
# Dataframe Progress: Added 19794 out of 20000
# Dataframe Progress: Added 19795 out of 20000
# Dataframe Progress: Added 19796 out of 20000
# Dataframe Progress: Added 19797 out of 20000
# Dataframe Progress: Added 19798 out of 20000
# Dataframe Progress: Added 19799 out of 20000
# Dataframe Progress: Added 19800 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 19801 out of 20000
# Dataframe Progress: Added 19802 out of 20000
# Dataframe Progress: Added 19803 out of 20000
# Dataframe Progress: Added 19804 out of 20000
# Dataframe Progress: Added 19805 out of 20000
# Dataframe Progress: Added 19806 out of 20000
# Dataframe Progress: Added 19807 out of 20000
# Dataframe Progress: Added 19808 out of 20000
# Dataframe Progress: Added 19809 out of 20000
# Dataframe Progress: Added 19810 out of 20000
# Dataframe Progress: Added 19811 out of 20000
# Dataframe Progress: Added 19812 out of 20000
# Dataframe Progress: Added 19813 out of 20000
# Dataframe Progress: Added 19814 out of 20000
# Dataframe Progress: Added 19815 out of 20000
# Dataframe Progress: Added 19816 out of 20000
# Dataframe Progress: Added 19817 out of 20000
# Dataframe Progress: Added 19818 out of 20000
# Dataframe Progress: Added 19819 out of 20000
# Dataframe Progress: Added 19820 out of 20000
# Dataframe Progress: Added 19821 out of 20000
# Dataframe Progress: Added 19822 out of 20000
# Dataframe Progress: Added 19823 out of 20000
# Dataframe Progress: Added 19824 out of 20000
# Dataframe Progress: Added 19825 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 19826 out of 20000
# Dataframe Progress: Added 19827 out of 20000
# Dataframe Progress: Added 19828 out of 20000
# Dataframe Progress: Added 19829 out of 20000
# Dataframe Progress: Added 19830 out of 20000
# Dataframe Progress: Added 19831 out of 20000
# Dataframe Progress: Added 19832 out of 20000
# Dataframe Progress: Added 19833 out of 20000
# Dataframe Progress: Added 19834 out of 20000
# Dataframe Progress: Added 19835 out of 20000
# Dataframe Progress: Added 19836 out of 20000
# Dataframe Progress: Added 19837 out of 20000
# Dataframe Progress: Added 19838 out of 20000
# Dataframe Progress: Added 19839 out of 20000
# Dataframe Progress: Added 19840 out of 20000
# Dataframe Progress: Added 19841 out of 20000
# Dataframe Progress: Added 19842 out of 20000
# Dataframe Progress: Added 19843 out of 20000
# Dataframe Progress: Added 19844 out of 20000
# Dataframe Progress: Added 19845 out of 20000
# Dataframe Progress: Added 19846 out of 20000
# Dataframe Progress: Added 19847 out of 20000
# Dataframe Progress: Added 19848 out of 20000
# Dataframe Progress: Added 19849 out of 20000
# Dataframe Progress: Added 19850 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 19851 out of 20000
# Dataframe Progress: Added 19852 out of 20000
# Dataframe Progress: Added 19853 out of 20000
# Dataframe Progress: Added 19854 out of 20000
# Dataframe Progress: Added 19855 out of 20000
# Dataframe Progress: Added 19856 out of 20000
# Dataframe Progress: Added 19857 out of 20000
# Dataframe Progress: Added 19858 out of 20000
# Dataframe Progress: Added 19859 out of 20000
# Dataframe Progress: Added 19860 out of 20000
# Dataframe Progress: Added 19861 out of 20000
# Dataframe Progress: Added 19862 out of 20000
# Dataframe Progress: Added 19863 out of 20000
# Dataframe Progress: Added 19864 out of 20000
# Dataframe Progress: Added 19865 out of 20000
# Dataframe Progress: Added 19866 out of 20000
# Dataframe Progress: Added 19867 out of 20000
# Dataframe Progress: Added 19868 out of 20000
# Dataframe Progress: Added 19869 out of 20000
# Dataframe Progress: Added 19870 out of 20000
# Dataframe Progress: Added 19871 out of 20000
# Dataframe Progress: Added 19872 out of 20000
# Dataframe Progress: Added 19873 out of 20000
# Dataframe Progress: Added 19874 out of 20000
# Dataframe Progress: Added 19875 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 19876 out of 20000
# Dataframe Progress: Added 19877 out of 20000
# Dataframe Progress: Added 19878 out of 20000
# Dataframe Progress: Added 19879 out of 20000
# Dataframe Progress: Added 19880 out of 20000
# Dataframe Progress: Added 19881 out of 20000
# Dataframe Progress: Added 19882 out of 20000
# Dataframe Progress: Added 19883 out of 20000
# Dataframe Progress: Added 19884 out of 20000
# Dataframe Progress: Added 19885 out of 20000
# Dataframe Progress: Added 19886 out of 20000
# Dataframe Progress: Added 19887 out of 20000
# Dataframe Progress: Added 19888 out of 20000
# Dataframe Progress: Added 19889 out of 20000
# Dataframe Progress: Added 19890 out of 20000
# Dataframe Progress: Added 19891 out of 20000
# Dataframe Progress: Added 19892 out of 20000
# Dataframe Progress: Added 19893 out of 20000
# Dataframe Progress: Added 19894 out of 20000
# Dataframe Progress: Added 19895 out of 20000
# Dataframe Progress: Added 19896 out of 20000
# Dataframe Progress: Added 19897 out of 20000
# Dataframe Progress: Added 19898 out of 20000
# Dataframe Progress: Added 19899 out of 20000
# Dataframe Progress: Added 19900 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 19901 out of 20000
# Dataframe Progress: Added 19902 out of 20000
# Dataframe Progress: Added 19903 out of 20000
# Dataframe Progress: Added 19904 out of 20000
# Dataframe Progress: Added 19905 out of 20000
# Dataframe Progress: Added 19906 out of 20000
# Dataframe Progress: Added 19907 out of 20000
# Dataframe Progress: Added 19908 out of 20000
# Dataframe Progress: Added 19909 out of 20000
# Dataframe Progress: Added 19910 out of 20000
# Dataframe Progress: Added 19911 out of 20000
# Dataframe Progress: Added 19912 out of 20000
# Dataframe Progress: Added 19913 out of 20000
# Dataframe Progress: Added 19914 out of 20000
# Dataframe Progress: Added 19915 out of 20000
# Dataframe Progress: Added 19916 out of 20000
# Dataframe Progress: Added 19917 out of 20000
# Dataframe Progress: Added 19918 out of 20000
# Dataframe Progress: Added 19919 out of 20000
# Dataframe Progress: Added 19920 out of 20000
# Dataframe Progress: Added 19921 out of 20000
# Dataframe Progress: Added 19922 out of 20000
# Dataframe Progress: Added 19923 out of 20000
# Dataframe Progress: Added 19924 out of 20000
# Dataframe Progress: Added 19925 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 19926 out of 20000
# Dataframe Progress: Added 19927 out of 20000
# Dataframe Progress: Added 19928 out of 20000
# Dataframe Progress: Added 19929 out of 20000
# Dataframe Progress: Added 19930 out of 20000
# Dataframe Progress: Added 19931 out of 20000
# Dataframe Progress: Added 19932 out of 20000
# Dataframe Progress: Added 19933 out of 20000
# Dataframe Progress: Added 19934 out of 20000
# Dataframe Progress: Added 19935 out of 20000
# Dataframe Progress: Added 19936 out of 20000
# Dataframe Progress: Added 19937 out of 20000
# Dataframe Progress: Added 19938 out of 20000
# Dataframe Progress: Added 19939 out of 20000
# Dataframe Progress: Added 19940 out of 20000
# Dataframe Progress: Added 19941 out of 20000
# Dataframe Progress: Added 19942 out of 20000
# Dataframe Progress: Added 19943 out of 20000
# Dataframe Progress: Added 19944 out of 20000
# Dataframe Progress: Added 19945 out of 20000
# Dataframe Progress: Added 19946 out of 20000
# Dataframe Progress: Added 19947 out of 20000
# Dataframe Progress: Added 19948 out of 20000
# Dataframe Progress: Added 19949 out of 20000
# Dataframe Progress: Added 19950 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 19951 out of 20000
# Dataframe Progress: Added 19952 out of 20000
# Dataframe Progress: Added 19953 out of 20000
# Dataframe Progress: Added 19954 out of 20000
# Dataframe Progress: Added 19955 out of 20000
# Dataframe Progress: Added 19956 out of 20000
# Dataframe Progress: Added 19957 out of 20000
# Dataframe Progress: Added 19958 out of 20000
# Dataframe Progress: Added 19959 out of 20000
# Dataframe Progress: Added 19960 out of 20000
# Dataframe Progress: Added 19961 out of 20000
# Dataframe Progress: Added 19962 out of 20000
# Dataframe Progress: Added 19963 out of 20000
# Dataframe Progress: Added 19964 out of 20000
# Dataframe Progress: Added 19965 out of 20000
# Dataframe Progress: Added 19966 out of 20000
# Dataframe Progress: Added 19967 out of 20000
# Dataframe Progress: Added 19968 out of 20000
# Dataframe Progress: Added 19969 out of 20000
# Dataframe Progress: Added 19970 out of 20000
# Dataframe Progress: Added 19971 out of 20000
# Dataframe Progress: Added 19972 out of 20000
# Dataframe Progress: Added 19973 out of 20000
# Dataframe Progress: Added 19974 out of 20000
# Dataframe Progress: Added 19975 out of 20000
# Number of Work Objects to use: 25
# Dataframe Progress: Added 19976 out of 20000
# Dataframe Progress: Added 19977 out of 20000
# Dataframe Progress: Added 19978 out of 20000
# Dataframe Progress: Added 19979 out of 20000
# Dataframe Progress: Added 19980 out of 20000
# Dataframe Progress: Added 19981 out of 20000
# Dataframe Progress: Added 19982 out of 20000
# Dataframe Progress: Added 19983 out of 20000
# Dataframe Progress: Added 19984 out of 20000
# Dataframe Progress: Added 19985 out of 20000
# Dataframe Progress: Added 19986 out of 20000
# Dataframe Progress: Added 19987 out of 20000
# Dataframe Progress: Added 19988 out of 20000
# Dataframe Progress: Added 19989 out of 20000
# Dataframe Progress: Added 19990 out of 20000
# Dataframe Progress: Added 19991 out of 20000
# Dataframe Progress: Added 19992 out of 20000
# Dataframe Progress: Added 19993 out of 20000
# Dataframe Progress: Added 19994 out of 20000
# Dataframe Progress: Added 19995 out of 20000
# Dataframe Progress: Added 19996 out of 20000
# Dataframe Progress: Added 19997 out of 20000
# Dataframe Progress: Added 19998 out of 20000
# Dataframe Progress: Added 19999 out of 20000
# Dataframe Progress: Added 20000 out of 20000

# %% [markdown]
# #### Checks it is in proper form

# %%
len(wrangled_work_df)
# Out:
# 20000

# %% [markdown]
# #### Store the values in Sqlite3 Database (to avoid hitting the Rate limit and redundant API calls)

# %%
import sqlite3

# Convert list columns to JSON strings
wrangled_work_df['referenced_works'] = wrangled_work_df['referenced_works'].apply(json.dumps)
wrangled_work_df['related_work_titles'] = wrangled_work_df['related_work_titles'].apply(json.dumps)
wrangled_work_df['ngrams'] = wrangled_work_df['ngrams'].apply(json.dumps)

wrangled_work_df['nearest_related_work'] = wrangled_work_df['nearest_related_work'].apply(json.dumps)
wrangled_work_df['nearest_referenced_work'] = wrangled_work_df['nearest_referenced_work'].apply(json.dumps)
wrangled_work_df['nearest_ngrams_work'] = wrangled_work_df['nearest_ngrams_work'].apply(json.dumps)



# Connect to SQLite
works_db = sqlite3.connect("works.db")

# Convert DataFrame to SQLite
wrangled_work_df.to_sql('works_table', works_db, index=False, if_exists='replace')

# Save (commit) the changes
works_db.commit()

# Close the connection
works_db.close()

# %% [markdown]
# ### Use the Voyage API to Cluster and find Top-k values

# %% [markdown]
# ##### Set the environment

# %%
import os
import voyageai
os.environ['VOYAGE_API_KEY'] = "pa-k2_wb1Mj37_Ppl1FFBmCvu-ybdIKZzels0GeMF7PnUI"
vo = voyageai.Client(api_key=os.environ.get("VOYAGE_API_KEY"),)

# %% [markdown]
# **Nearest neighbor Search:**
# ##### We can find a few closest embeddings in the documents embeddings based on the cosine similarity,
# ##### and retrieve the corresponding document using the nearest_neighbors function.

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def k_nearest_neighbors(query_embedding, documents_embeddings, k=5):
  query_embedding = np.array(query_embedding) # convert to numpy array
  documents_embeddings = np.array(documents_embeddings) # convert to numpy array

  # Reshape the query vector embedding to a matrix of shape (1, n) to make it compatible with cosine_similarity
  query_embedding = query_embedding.reshape(1, -1)

  # Calculate the similarity for each item in data
  cosine_sim = cosine_similarity(query_embedding, documents_embeddings)

  # Sort the data by similarity in descending order and take the top k items
  sorted_indices = np.argsort(cosine_sim[0])[::-1]

  # Take the top k related embeddings
  top_k_related_indices = sorted_indices[:k]
  top_k_related_embeddings = documents_embeddings[sorted_indices[:k]]
  top_k_related_embeddings = [list(row[:]) for row in top_k_related_embeddings] # convert to list

  return top_k_related_embeddings, top_k_related_indices

# %% [markdown]
# ##### perform the **$k$-nearest neighbors Search ($k$-NN)** the nearest/closest query , document pair.
# ##### I will be using the **voyage-lite-02-instruct** model since this version is the best performing model for clustering tasks.

# %%
import sqlite3
import json
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import requests
import time

# Connect to the SQLite database
works_db = sqlite3.connect("works.db")

# Create a cursor
work_cursor = works_db.cursor()

# Execute a SELECT query
query = "SELECT * FROM works_table"
work_cursor.execute(query)

# Fetch all results
results = work_cursor.fetchall()

# Iterate over the results
for index, result in enumerate(results):
    try:
        (work_id,
         title,
         referenced_works_json,
         related_work_titles_json,
         ngrams_json,
         nearest_referenced_work_json,
         nearest_related_work_json,
         nearest_ngrams_work_json) = result

        # Parse JSON strings back to Python objects
        referenced_works = json.loads(referenced_works_json)
        related_work_titles = json.loads(related_work_titles_json)
        ngrams = json.loads(ngrams_json)
        
        

        # Lists to store retrieved documents
        nearest_referenced_work = ""
        nearest_related_work = ""
        nearest_ngrams_work = ""

        # Embed the title
        title_embedding = vo.embed([title], model="voyage-lite-02-instruct", input_type="query").embeddings[0]

        # Store the referenced_works for processing
        if referenced_works:
            # Store the referenced for processing
            referenced_documents = referenced_works

            # Embed the referenced
            referenced_documents_embeddings = vo.embed(referenced_documents, model="voyage-lite-02-instruct", input_type="document").embeddings

            # Find the nearest neighbor and store in the nearest referenced work
            retrieved_embds, retrieved_embd_indices = k_nearest_neighbors(title_embedding, referenced_documents_embeddings, k=1)
            nearest_referenced_work = referenced_documents[retrieved_embd_indices[0]]

        if related_work_titles:
            # Store the related_works for processing
            related_documents = related_work_titles

            # Embed the related_works
            related_documents_embeddings = vo.embed(related_documents, model="voyage-lite-02-instruct", input_type="document").embeddings

            # Find the nearest neighbor and store in the nearest related work
            retrieved_embds, retrieved_embd_indices = k_nearest_neighbors(title_embedding, related_documents_embeddings, k=1)
            nearest_related_work = related_documents[retrieved_embd_indices[0]]

        # Embed the ngrams if the list has values
        if ngrams:
            # Store the ngrams_works for processing
            ngrams_documents = ngrams

            # Embed the ngrams_works
            ngrams_documents_embeddings = vo.embed(ngrams_documents, model="voyage-lite-02-instruct", input_type="document").embeddings

            # Find the nearest neighbor and store in the nearest ngram work
            retrieved_embds, retrieved_embd_indices = k_nearest_neighbors(title_embedding, ngrams_documents_embeddings, k=1)
            nearest_ngrams_work = ngrams_documents[retrieved_embd_indices[0]]

        # Update the SQLite database with the retrieved documents
        update_query = f"UPDATE works_table SET nearest_related_work = ?, nearest_referenced_work = ?, nearest_ngrams_work = ? WHERE work_id = ?"
        work_cursor.execute(update_query, (nearest_related_work, nearest_referenced_work, nearest_ngrams_work, work_id))
        works_db.commit()

    except Exception as e:
        print(f"Error processing work_id {work_id}: {e}")
        continue

    finally:
        # Show the progress of Nearest Neighbor extraction process
        print(f"Extraction progress at {index + 1} out of {len(results)}")

        # Added a sleep function for 60 seconds every time index is a multiple of 300, because of Rate Limit caution
        if (index + 1) % 300 == 0:
            print(f"Sleeping for 60 seconds at index {index + 1}...")
            # time.sleep(60) # commented out for testing purposes

# Close the cursor and connection
work_cursor.close()
works_db.close()
# Out:
# Extraction progress at 1 out of 20000
# Extraction progress at 2 out of 20000
# Extraction progress at 3 out of 20000
# Extraction progress at 4 out of 20000
# Extraction progress at 5 out of 20000
# Extraction progress at 6 out of 20000
# Extraction progress at 7 out of 20000
# Extraction progress at 8 out of 20000
# Extraction progress at 9 out of 20000
# Extraction progress at 10 out of 20000
# Extraction progress at 11 out of 20000
# Extraction progress at 12 out of 20000
# Extraction progress at 13 out of 20000
# Extraction progress at 14 out of 20000
# Extraction progress at 15 out of 20000
# Extraction progress at 16 out of 20000
# Extraction progress at 17 out of 20000
# Extraction progress at 18 out of 20000
# Extraction progress at 19 out of 20000
# Extraction progress at 20 out of 20000
# Extraction progress at 21 out of 20000
# Extraction progress at 22 out of 20000
# Extraction progress at 23 out of 20000
# Extraction progress at 24 out of 20000
# Extraction progress at 25 out of 20000
# Extraction progress at 26 out of 20000
# Extraction progress at 27 out of 20000
# Extraction progress at 28 out of 20000
# Extraction progress at 29 out of 20000
# Extraction progress at 30 out of 20000
# Extraction progress at 31 out of 20000
# Extraction progress at 32 out of 20000
# Extraction progress at 33 out of 20000
# Extraction progress at 34 out of 20000
# Extraction progress at 35 out of 20000
# Extraction progress at 36 out of 20000
# Extraction progress at 37 out of 20000
# Extraction progress at 38 out of 20000
# Extraction progress at 39 out of 20000
# Extraction progress at 40 out of 20000
# Extraction progress at 41 out of 20000
# Extraction progress at 42 out of 20000
# Extraction progress at 43 out of 20000
# Extraction progress at 44 out of 20000
# Extraction progress at 45 out of 20000
# Extraction progress at 46 out of 20000
# Extraction progress at 47 out of 20000
# Extraction progress at 48 out of 20000
# Extraction progress at 49 out of 20000
# Extraction progress at 50 out of 20000
# Extraction progress at 51 out of 20000
# Extraction progress at 52 out of 20000
# Extraction progress at 53 out of 20000
# Extraction progress at 54 out of 20000
# Extraction progress at 55 out of 20000
# Extraction progress at 56 out of 20000
# Extraction progress at 57 out of 20000
# Extraction progress at 58 out of 20000
# Extraction progress at 59 out of 20000
# Extraction progress at 60 out of 20000
# Extraction progress at 61 out of 20000
# Extraction progress at 62 out of 20000
# Extraction progress at 63 out of 20000
# Extraction progress at 64 out of 20000
# Extraction progress at 65 out of 20000
# Extraction progress at 66 out of 20000
# Extraction progress at 67 out of 20000
# Extraction progress at 68 out of 20000
# Extraction progress at 69 out of 20000
# Extraction progress at 70 out of 20000
# Extraction progress at 71 out of 20000
# Extraction progress at 72 out of 20000
# Extraction progress at 73 out of 20000
# Extraction progress at 74 out of 20000
# Extraction progress at 75 out of 20000
# Extraction progress at 76 out of 20000
# Extraction progress at 77 out of 20000
# Extraction progress at 78 out of 20000
# Extraction progress at 79 out of 20000
# Extraction progress at 80 out of 20000
# Extraction progress at 81 out of 20000
# Extraction progress at 82 out of 20000
# Extraction progress at 83 out of 20000
# Extraction progress at 84 out of 20000
# Extraction progress at 85 out of 20000
# Extraction progress at 86 out of 20000
# Extraction progress at 87 out of 20000
# Extraction progress at 88 out of 20000
# Extraction progress at 89 out of 20000
# Extraction progress at 90 out of 20000
# Extraction progress at 91 out of 20000
# Extraction progress at 92 out of 20000
# Extraction progress at 93 out of 20000
# Extraction progress at 94 out of 20000
# Extraction progress at 95 out of 20000
# Extraction progress at 96 out of 20000
# Extraction progress at 97 out of 20000
# Extraction progress at 98 out of 20000
# Error processing work_id W4248329039: The request body is not valid JSON, or some arguments were not specified properly. In particular, Value '[None]' supplied for argument 'input' is not a valid string; Value 'None' supplied for argument 'input' is not a valid string
# Extraction progress at
# Extraction progress at 193 out of 20000
# Extraction progress at 194 out of 20000
# Extraction progress at 195 out of 20000
# Extraction progress at 196 out of 20000
# Extraction progress at 197 out of 20000
# Extraction progress at 198 out of 20000
# Extraction progress at 199 out of 20000
# Extraction progress at 200 out of 20000
# Extraction progress at 201 out of 20000
# Extraction progress at 202 out of 20000
# Extraction progress at 203 out of 20000
# Extraction progress at 204 out of 20000
# Extraction progress at 205 out of 20000
# Extraction progress at 206 out of 20000
# Extraction progress at 207 out of 20000
# Extraction progress at 208 out of 20000
# Extraction progress at 209 out of 20000
# Extraction progress at 210 out of 20000
# Extraction progress at 211 out of 20000
# Extraction progress at 212 out of 20000
# Extraction progress at 213 out of 20000
# Extraction progress at 214 out of 20000
# Extraction progress at 215 out of 20000
# Extraction progress at 216 out of 20000
# Extraction progress at 217 out of 20000
# Extraction progress at 218 out of 20000
# Extraction progress at 219 out of 20000
# Extraction progress at 220 out of 20000
# Extraction progress at 221 out of 20000
# Extraction progress at 222 out of 20000
# Extraction progress at 223 out of 20000
# Extraction progress at 224 out of 20000
# Extraction progress at 225 out of 20000
# Extraction progress at 226 out of 20000
# Extraction progress at 227 out of 20000
# Extraction progress at 228 out of 20000
# Extraction progress at 229 out of 20000
# Extraction progress at 230 out of 20000
# Extraction progress at 231 out of 20000
# Extraction progress at 232 out of 20000
# Extraction progress at 233 out of 20000
# Extraction progress at 234 out of 20000
# Extraction progress at 235 out of 20000
# Extraction progress at 236 out of 20000
# Extraction progress at 237 out of 20000
# Extraction progress at 238 out of 20000
# Extraction progress at 239 out of 20000
# Extraction progress at 240 out of 20000
# Extraction progress at 241 out of 20000
# Extraction progress at 242 out of 20000
# Extraction progress at 243 out of 20000
# Extraction progress at 244 out of 20000
# Extraction progress at 245 out of 20000
# Extraction progress at 246 out of 20000
# Extraction progress at 247 out of 20000
# Extraction progress at 248 out of 20000
# Extraction progress at 249 out of 20000
# Extraction progress at 250 out of 20000
# Extraction progress at 251 out of 20000
# Extraction progress at 252 out of 20000
# Extraction progress at 253 out of 20000
# Extraction progress at 254 out of 20000
# Extraction progress at 255 out of 20000
# Extraction progress at 256 out of 20000
# Error processing work_id W4243897703: The request body is not valid JSON, or some arguments were not specified properly. In particular, Value '[None]' supplied for argument 'input' is not a valid string; Value 'None' supplied for argument 'input' is not a valid string
# Extraction progress at 257 out of 20000
# Extraction progress at 258 out of 20000
# Extraction progress at 259 out of 20000
# Extraction progress at 260 out of 20000
# Extraction progress at 261 out of 20000
# Extraction progress at 262 out of 20000
# Extraction progress at 263 out of 20000
# Extraction progress at 264 out of 20000
# Extraction progress at 265 out of 20000
# Extraction progress at 266 out of 20000
# Extraction progress at 267 out of 20000
# Extraction progress at 268 out of 20000
# Extraction progress at 269 out of 20000
# Extraction progress at 270 out of 20000
# Extraction progress at 271 out of 20000
# Extraction progress at 272 out of 20000
# Extraction progress at 273 out of 20000
# Extraction progress at 274 out of 20000
# Extraction progress at 275 out of 20000
# Extraction progress at 276 out of 20000
# Extraction progress at 277 out of 20000
# Extraction progress at 278 out of 20000
# Extraction progress at 279 out of 20000
# Extraction progress at 280 out of 20000
# Extraction progress at 281 out of 20000
# Extraction progress at 282 out of 20000
# Extraction progress at 283 out of 20000
# Extraction progress at 466 out of 20000
# Extraction progress at 467 out of 20000
# Extraction progress at 468 out of 20000
# Extraction progress at 469 out of 20000
# Extraction progress at 470 out of 20000
# Extraction progress at 471 out of 20000
# Extraction progress at 472 out of 20000
# Extraction progress at 473 out of 20000
# Extraction progress at 474 out of 20000
# Extraction progress at 475 out of 20000
# Extraction progress at 476 out of 20000
# Extraction progress at 477 out of 20000
# Extraction progress at 478 out of 20000
# Extraction progress at 479 out of 20000
# Extraction progress at 480 out of 20000
# Extraction progress at 481 out of 20000
# Extraction progress at 482 out of 20000
# Extraction progress at 483 out of 20000
# Extraction progress at 484 out of 20000
# Extraction progress at 485 out of 20000
# Extraction progress at 486 out of 20000
# Extraction progress at 487 out of 20000
# Extraction progress at 488 out of 20000
# Extraction progress at 489 out of 20000
# Extraction progress at 490 out of 20000
# Extraction progress at 491 out of 20000
# Extraction progress at 492 out of 20000
# Extraction progress at 493 out of 20000
# Extraction progress at 494 out of 20000
# Extraction progress at 495 out of 20000
# Extraction progress at 496 out of 20000
# Extraction progress at 497 out of 20000
# Extraction progress at 498 out of 20000
# Extraction progress at 499 out of 20000
# Extraction progress at 500 out of 20000
# Extraction progress at 501 out of 20000
# Extraction progress at 502 out of 20000
# Extraction progress at 503 out of 20000
# Extraction progress at 504 out of 20000
# Extraction progress at 505 out of 20000
# Extraction progress at 506 out of 20000
# Extraction progress at 507 out of 20000
# Extraction progress at 508 out of 20000
# Extraction progress at 509 out of 20000
# Extraction progress at 510 out of 20000
# Extraction progress at 511 out of 20000
# Extraction progress at 512 out of 20000
# Extraction progress at 513 out of 20000
# Extraction progress at 514 out of 20000
# Extraction progress at 515 out of 20000
# Extraction progress at 516 out of 20000
# Extraction progress at 517 out of 20000
# Extraction progress at 518 out of 20000
# Extraction progress at 519 out of 20000
# Extraction progress at 520 out of 20000
# Extraction progress at 521 out of 20000
# Extraction progress at 522 out of 20000
# Extraction progress at 523 out of 20000
# Extraction progress at 524 out of 20000
# Extraction progress at 525 out of 20000
# Extraction progress at 526 out of 20000
# Extraction progress at 527 out of 20000
# Extraction progress at 528 out of 20000
# Extraction progress at 529 out of 20000
# Extraction progress at 530 out of 20000
# Extraction progress at 531 out of 20000
# Extraction progress at 532 out of 20000
# Extraction progress at 533 out of 20000
# Extraction progress at 534 out of 20000
# Extraction progress at 535 out of 20000
# Extraction progress at 536 out of 20000
# Extraction progress at 537 out of 20000
# Extraction progress at 538 out of 20000
# Extraction progress at 539 out of 20000
# Extraction progress at 540 out of 20000
# Extraction progress at 541 out of 20000
# Extraction progress at 542 out of 20000
# Extraction progress at 543 out of 20000
# Extraction progress at 544 out of 20000
# Extraction progress at 545 out of 20000
# Extraction progress at 546 out of 20000
# Extraction progress at 547 out of 20000
# Extraction progress at 548 out of 20000
# Extraction progress at 549 out of 20000
# Extraction progress at 550 out of 20000
# Extraction progress at 551 out of 20000
# Extraction progress at 552 out of 20000
# Extraction progress at 553 out of 20000
# Extraction progress at 554 out of 20000
# Extraction progress at 555 out of 20000
# Extraction progress at 556 out of 20000
The request body is not valid JSON, or some arguments were not specified properly. In particular, Value '[None]' supplied for argument 'input' is not a valid string; Value 'None' supplied for argument 'input' is not a valid string
# Extraction progress at 680 out of 20000
# Extraction progress at 681 out of 20000
# Extraction progress at 682 out of 20000
# Extraction progress at 683 out of 20000
# Extraction progress at 684 out of 20000
# Extraction progress at 685 out of 20000
# Extraction progress at 686 out of 20000
# Extraction progress at 687 out of 20000
# Extraction progress at 688 out of 20000
# Extraction progress at 689 out of 20000
# Extraction progress at 690 out of 20000
# Extraction progress at 691 out of 20000
# Extraction progress at 692 out of 20000
# Extraction progress at 693 out of 20000
# Extraction progress at 694 out of 20000
# Extraction progress at 695 out of 20000
# Extraction progress at 696 out of 20000
# Extraction progress at 697 out of 20000
# Extraction progress at 698 out of 20000
# Extraction progress at 699 out of 20000
# Extraction progress at 700 out of 20000
# Extraction progress at 701 out of 20000
# Extraction progress at 702 out of 20000
# Extraction progress at 703 out of 20000
# Extraction progress at 704 out of 20000
# Extraction progress at 705 out of 20000
# Extraction progress at 706 out of 20000
# Extraction progress at 707 out of 20000
# Extraction progress at 708 out of 20000
# Extraction progress at 709 out of 20000
# Extraction progress at 710 out of 20000
# Extraction progress at 711 out of 20000
# Extraction progress at 712 out of 20000
# Extraction progress at 713 out of 20000
# Extraction progress at 714 out of 20000
# Extraction progress at 715 out of 20000
# Extraction progress at 716 out of 20000
# Extraction progress at 717 out of 20000
# Extraction progress at 718 out of 20000
# Extraction progress at 719 out of 20000
# Extraction progress at 720 out of 20000
# Extraction progress at 721 out of 20000
# Extraction progress at 722 out of 20000
# Extraction progress at 723 out of 20000
# Extraction progress at 724 out of 20000
# Extraction progress at 725 out of 20000
# Extraction progress at 726 out of 20000
# Extraction progress at 727 out of 20000
# Extraction progress at 728 out of 20000
# Extraction progress at 729 out of 20000
# Extraction progress at 730 out of 20000
# Extraction progress at 731 out of 20000
# Extraction progress at 732 out of 20000
# Extraction progress at 733 out of 20000
# Extraction progress at 734 out of 20000
# Extraction progress at 735 out of 20000
# Extraction progress at 736 out of 20000
# Extraction progress at 737 out of 20000
# Extraction progress at 738 out of 20000
# Extraction progress at 739 out of 20000
# Extraction progress at 740 out of 20000
# Extraction progress at 741 out of 20000
# Extraction progress at 742 out of 20000
# Extraction progress at 743 out of 20000
# Extraction progress at 744 out of 20000
# Extraction progress at 745 out of 20000
# Extraction progress at 746 out of 20000
# Extraction progress at 747 out of 20000
# Extraction progress at 748 out of 20000
# Extraction progress at 749 out of 20000
# Extraction progress at 750 out of 20000
# Extraction progress at 751 out of 20000
# Extraction progress at 752 out of 20000
# Extraction progress at 753 out of 20000
# Extraction progress at 754 out of 20000
# Extraction progress at 755 out of 20000
# Extraction progress at 756 out of 20000
# Extraction progress at 757 out of 20000
# Extraction progress at 758 out of 20000
# Extraction progress at 759 out of 20000
# Extraction progress at 760 out of 20000
# Extraction progress at 761 out of 20000
# Extraction progress at 762 out of 20000
# Extraction progress at 763 out of 20000
# Extraction progress at 764 out of 20000
# Extraction progress at 765 out of 20000
# Extraction progress at 766 out of 20000
# Extraction progress at 767 out of 20000
# Extraction progress at 768 out of 20000
# Extraction progress at 769 out of 20000
# Extraction progress at 770 out of 20000
# Extraction progress at 771 out of 20000
# Extraction progress at 772 out of 20000
# Extraction progress at 773 out of 20000
# Extraction progress at 774 out of 20000
# Extraction progress at 775 out of 20000
# Extraction progress at 776 out of 20000
# Extraction progress at 777 out of 20000
# Extraction progress at 778 out of 20000
# Extraction progress at 779 out of 20000
# Extraction progress at 780 out of 20000
# Extraction progress at 781 out of 20000
# Extraction progress at 782 out of 20000
# Extraction progress at 783 out of 20000
# Extraction progress at 784 out of 20000
# Extraction progress at 785 out of 20000
# Extraction progress at 786 out of 20000
# Extraction progress at 787 out of 20000
# Extraction progress at 788 out of 20000
# Extraction progress at 789 out of 20000
# Extraction progress at 790 out of 20000
# Extraction progress at 791 out of 20000
# Extraction progress at 792 out of 20000
# Extraction progress at 793 out of 20000
# Extraction progress at 794 out of 20000
# Extraction progress at 795 out of 20000
# Extraction progress at 796 out of 20000
# Extraction progress at 797 out of 20000
# Extraction progress at 798 out of 20000
# Extraction progress at 799 out of 20000
# Extraction progress at 800 out of 20000
# Extraction progress at 801 out of 20000
# Extraction progress at 802 out of 20000
# Extraction progress at 803 out of 20000
# Extraction progress at 804 out of 20000
# Extraction progress at 805 out of 20000
# Extraction progress at 806 out of 20000
# Extraction progress at 807 out of 20000
# Extraction progress at 808 out of 20000
# Extraction progress at 809 out of 20000
# Extraction progress at 810 out of 20000
# Extraction progress at 811 out of 20000
# Extraction progress at 812 out of 20000
# Extraction progress at 813 out of 20000
# Extraction progress at 814 out of 20000
# Extraction progress at 815 out of 20000
# Extraction progress at 816 out of 20000
# Extraction progress at 817 out of 20000
# Extraction progress at 818 out of 20000
# Extraction progress at 819 out of 20000
# Extraction progress at 820 out of 20000
# Extraction progress at 821 out of 20000
# Extraction progress at 822 out of 20000
# Extraction progress at 823 out of 20000
# Extraction progress at 824 out of 20000
# Extraction progress at 825 out of 20000
# Extraction progress at 826 out of 20000
# Extraction progress at 827 out of 20000
# Extraction progress at 828 out of 20000
# Extraction progress at 829 out of 20000
# Extraction progress at 830 out of 20000
# Extraction progress at 831 out of 20000
# Extraction progress at 832 out of 20000
# Extraction progress at 833 out of 20000
# Extraction progress at 834 out of 20000
# Extraction progress at 835 out of 20000
# Extraction progress at 836 out of 20000
# Extraction progress at 837 out of 20000
# Extraction progress at 838 out of 20000
# Extraction progress at 839 out of 20000
# Extraction progress at 840 out of 20000
# Extraction progress at 841 out of 20000
# Extraction progress at 842 out of 20000
# Extraction progress at 843 out of 20000
# Extraction progress at 844 out of 20000
# Extraction progress at 845 out of 20000
# Extraction progress at 846 out of 20000
# Extraction progress at 847 out of 20000
# Extraction progress at 848 out of 20000
# Extraction progress at 849 out of 20000
# Extraction progress at 850 out of 20000
# Extraction progress at 851 out of 20000
# Extraction progress at 852 out of 20000
# Extraction progress at 853 out of 20000
The request body is not valid JSON, or some arguments were not specified properly. In particular, Value '[None]' supplied for argument 'input' is not a valid string; Value 'None' supplied for argument 'input' is not a valid string
# Extraction progress at 1038 out of 20000
# Extraction progress at 1039 out of 20000
# Extraction progress at 1040 out of 20000
# Extraction progress at 1041 out of 20000
# Extraction progress at 1042 out of 20000
# Extraction progress at 1043 out of 20000
# Extraction progress at 1044 out of 20000
# Extraction progress at 1045 out of 20000
# Extraction progress at 1046 out of 20000
# Extraction progress at 1047 out of 20000
# Extraction progress at 1048 out of 20000
# Extraction progress at 1049 out of 20000
# Extraction progress at 1050 out of 20000
# Extraction progress at 1051 out of 20000
# Extraction progress at 1052 out of 20000
# Extraction progress at 1053 out of 20000
# Extraction progress at 1054 out of 20000
# Extraction progress at 1055 out of 20000
# Extraction progress at 1056 out of 20000
# Extraction progress at 1057 out of 20000
# Extraction progress at 1058 out of 20000
# Extraction progress at 1059 out of 20000
# Extraction progress at 1060 out of 20000
# Extraction progress at 1061 out of 20000
# Extraction progress at 1062 out of 20000
# Extraction progress at 1063 out of 20000
# Extraction progress at 1064 out of 20000
# Extraction progress at 1065 out of 20000
# Extraction progress at 1066 out of 20000
# Extraction progress at 1067 out of 20000
# Extraction progress at 1068 out of 20000
# Extraction progress at 1069 out of 20000
# Extraction progress at 1070 out of 20000
# Extraction progress at 1071 out of 20000
# Extraction progress at 1072 out of 20000
# Extraction progress at 1073 out of 20000
# Extraction progress at 1074 out of 20000
# Extraction progress at 1075 out of 20000
# Extraction progress at 1076 out of 20000
# Extraction progress at 1077 out of 20000
# Extraction progress at 1078 out of 20000
# Extraction progress at 1079 out of 20000
# Extraction progress at 1080 out of 20000
# Extraction progress at 1081 out of 20000
# Extraction progress at 1082 out of 20000
# Extraction progress at 1083 out of 20000
# Extraction progress at 1084 out of 20000
# Extraction progress at 1085 out of 20000
# Extraction progress at 1086 out of 20000
# Extraction progress at 1087 out of 20000
# Extraction progress at 1088 out of 20000
# Extraction progress at 1089 out of 20000
# Extraction progress at 1090 out of 20000
# Extraction progress at 1091 out of 20000
# Extraction progress at 1092 out of 20000
# Extraction progress at 1093 out of 20000
# Extraction progress at 1094 out of 20000
# Extraction progress at 1095 out of 20000
# Extraction progress at 1096 out of 20000
# Extraction progress at 1097 out of 20000
# Extraction progress at 1098 out of 20000
# Extraction progress at 1099 out of 20000
# Extraction progress at 1100 out of 20000
# Error processing work_id W2372522894: The server is overloaded or not ready yet.
# Extraction progress at 1101 out of 20000
# Extraction progress at 1102 out of 20000
# Extraction progress at 1103 out of 20000
# Extraction progress at 1104 out of 20000
# Extraction progress at 1105 out of 20000
# Extraction progress at 1106 out of 20000
# Extraction progress at 1107 out of 20000
# Extraction progress at 1108 out of 20000
# Extraction progress at 1109 out of 20000
# Extraction progress at 1110 out of 20000
# Extraction progress at 1111 out of 20000
# Extraction progress at 1112 out of 20000
# Extraction progress at 1113 out of 20000
# Extraction progress at 1114 out of 20000
# Extraction progress at 1115 out of 20000
# Error processing work_id W4230963353: The request body is not valid JSON, or some arguments were not specified properly. In particular, Value '[None]' supplied for argument 'input' is not a valid string; Value 'None' supplied for argument 'input' is not a valid string
# Extraction progress at
# Extraction progress at 19956 out of 20000
# Extraction progress at 19957 out of 20000
# Extraction progress at 19958 out of 20000
# Extraction progress at 19959 out of 20000
# Extraction progress at 19960 out of 20000
# Extraction progress at 19961 out of 20000
# Extraction progress at 19962 out of 20000
# Extraction progress at 19963 out of 20000
# Extraction progress at 19964 out of 20000
# Extraction progress at 19965 out of 20000
# Extraction progress at 19966 out of 20000
# Extraction progress at 19967 out of 20000
# Extraction progress at 19968 out of 20000
# Extraction progress at 19969 out of 20000
# Extraction progress at 19970 out of 20000
# Extraction progress at 19971 out of 20000
# Extraction progress at 19972 out of 20000
# Extraction progress at 19973 out of 20000
# Extraction progress at 19974 out of 20000
# Extraction progress at 19975 out of 20000
# Extraction progress at 19976 out of 20000
# Extraction progress at 19977 out of 20000
# Error processing work_id W4310677062: The request body is not valid JSON, or some arguments were not specified properly. In particular, Value '[None]' supplied for argument 'input' is not a valid string; Value 'None' supplied for argument 'input' is not a valid string
# Extraction progress at 19978 out of 20000
# Extraction progress at 19979 out of 20000
# Extraction progress at 19980 out of 20000
# Extraction progress at 19981 out of 20000
# Extraction progress at 19982 out of 20000
# Extraction progress at 19983 out of 20000
# Extraction progress at 19984 out of 20000
# Extraction progress at 19985 out of 20000
# Extraction progress at 19986 out of 20000
# Extraction progress at 19987 out of 20000
# Extraction progress at 19988 out of 20000
# Extraction progress at 19989 out of 20000
# Extraction progress at 19990 out of 20000
# Extraction progress at 19991 out of 20000
# Extraction progress at 19992 out of 20000
# Extraction progress at 19993 out of 20000
# Extraction progress at 19994 out of 20000
# Extraction progress at 19995 out of 20000
# Extraction progress at 19996 out of 20000
# Extraction progress at 19997 out of 20000
# Extraction progress at 19998 out of 20000
# Extraction progress at 19999 out of 20000
# Extraction progress at 20000 out of 20000

# %% [markdown]
# #### Extracting the Empty Nearest Neighbors. Since calculations did not happen in this rows

# %%
import sqlite3

# Connect to the SQLite database
works_db = sqlite3.connect("works.db")

# Create a cursor
work_cursor = works_db.cursor()

# Execute the SELECT query to get the count
query = "SELECT COUNT(*) FROM works_table WHERE nearest_related_work = '' AND nearest_referenced_work = '' AND nearest_ngrams_work = ''"
work_cursor.execute(query)

# Fetch the result
result = work_cursor.fetchone()

# Display the count
print(f"Count of rows where all three fields are empty: {result[0]}")

# Close the cursor and connection
work_cursor.close()
works_db.close()
# Out:
# Count of rows where all three fields are empty: 4052

# %% [markdown]
# #### Delete the Empty rows since they are not useful for our usecase

# %%
import sqlite3

# Connect to the SQLite database
works_db = sqlite3.connect("works.db")

# Create a cursor
work_cursor = works_db.cursor()

# Execute the DELETE query to delete rows with empty values
delete_query = "DELETE FROM works_table WHERE nearest_related_work = '' AND nearest_referenced_work = '' AND nearest_ngrams_work = ''"
work_cursor.execute(delete_query)

# Commit the changes
works_db.commit()

# Display the number of rows deleted
print(f"Number of rows deleted: {work_cursor.rowcount}")

# Close the cursor and connection
work_cursor.close()
works_db.close()
# Out:
# Number of rows deleted: 4052

# %% [markdown]
# #### **Make a training pair** using the column values from the table. Using the calculated 15948 rows.

# %% [markdown]
# #### Title Refereced Work JSON

# %%
import json
import sqlite3

# Connect to the SQLite database
works_db = sqlite3.connect("works.db")

# Create a cursor
work_cursor = works_db.cursor()

# Execute a SELECT query only the rows having value
query = "SELECT * FROM works_table WHERE length(nearest_referenced_work) > 0"
work_cursor.execute(query)

# Fetch all results
results = work_cursor.fetchall()

# Define the path for the JSONL file
jsonl_file_path = "title_referenced_work.jsonl"

# Open the JSONL file in write mode
with open(jsonl_file_path, "w") as jsonl_file:
    # Iterate over the results
    for result in results:
        work_id, title, referenced_works_json, related_work_titles_json, ngrams_json, \
        nearest_related_work, nearest_referenced_work, nearest_ngrams_work = result

        # Extract values for JSONL format
        anchor_text = title
        positive_text = nearest_referenced_work

        # Create a dictionary for positive pairs
        positive_pairs = {"texts": [anchor_text, positive_text]}

        # Write the positive pairs dictionary as a JSON string to the JSONL file
        jsonl_file.write(json.dumps(positive_pairs) + "\n")

# Close the cursor and connection
work_cursor.close()
works_db.close()

# %% [markdown]
# #### Title Related Work JSON

# %%
import json
import sqlite3

# Connect to the SQLite database
works_db = sqlite3.connect("works.db")

# Create a cursor
work_cursor = works_db.cursor()

# Execute a SELECT query only the rows having value and limiting the number to 10k 
# Since we have a lot of related work data 
query = "SELECT * FROM works_table WHERE length(nearest_related_work) > 0 LIMIT 10000"
work_cursor.execute(query)

# Fetch all results
results = work_cursor.fetchall()

# Define the path for the JSONL file
jsonl_file_path = "title_related_work.jsonl"

# Open the JSONL file in write mode
with open(jsonl_file_path, "w") as jsonl_file:
    # Iterate over the results
    for result in results:
        work_id, title, referenced_works_json, related_work_titles_json, ngrams_json, \
        nearest_related_work, nearest_referenced_work, nearest_ngrams_work = result

        # Extract values for JSONL format
        anchor_text = title
        positive_text = nearest_related_work

        # Create a dictionary for positive pairs
        positive_pairs = {"texts": [anchor_text, positive_text]}

        # Write the positive pairs dictionary as a JSON string to the JSONL file
        jsonl_file.write(json.dumps(positive_pairs) + "\n")

# Close the cursor and connection
work_cursor.close()
works_db.close()

# %% [markdown]
# #### Title Ngrams Work JSON

# %%
import json
import sqlite3

# Connect to the SQLite database
works_db = sqlite3.connect("works.db")

# Create a cursor
work_cursor = works_db.cursor()

# Execute a SELECT query only the rows having value
query = "SELECT * FROM works_table WHERE length(nearest_ngrams_work) > 0"
work_cursor.execute(query)

# Fetch all results
results = work_cursor.fetchall()

# Define the path for the JSONL file
jsonl_file_path = "title_ngrams_work.jsonl"

# Open the JSONL file in write mode
with open(jsonl_file_path, "w") as jsonl_file:
    # Iterate over the results
    for result in results:
        work_id, title, referenced_works_json, related_work_titles_json, ngrams_json, \
        nearest_related_work, nearest_referenced_work, nearest_ngrams_work = result

        # Extract values for JSONL format
        anchor_text = title
        positive_text = nearest_ngrams_work

        # Create a dictionary for positive pairs
        positive_pairs = {"texts": [anchor_text, positive_text]}

        # Write the positive pairs dictionary as a JSON string to the JSONL file
        jsonl_file.write(json.dumps(positive_pairs) + "\n")

# Close the cursor and connection
work_cursor.close()
works_db.close()

# %% [markdown]
# ### Topics

# %% [markdown]
# #### 4. Training pairs for Topic display name and keywords

# %%
import requests
import json
import time

def fetch_and_store_data(url, output_file): 
    # Fetch data from the URL
    response = requests.get(url)
    data = response.json()

    # Extract relevant information and store in the desired format
    results = data.get("results", [])
    formatted_data = []

    for result in results:
        display_name = result.get("display_name", "")
        keywords = result.get("keywords", [])
        
        if keywords:
            # Extracting the top-scored keyword text
            top_keyword = keywords[0]        
            # Creating the structure {"texts": ["display_name", "key"]}
            formatted_entry = {"texts": [display_name, top_keyword]}
            formatted_data.append(formatted_entry)

    # Write to a .jsonl file
    with open(output_file, "a") as jsonl_file:
        for entry in formatted_data:
            jsonl_file.write(json.dumps(entry) + "\n")

if __name__ == "__main__":
    # Initialize counters
    current_page = 1
    total_entries_count = 0
    target_count = 10000
    # Specify the URL and output file
    output_jsonl_file = "topic_name_key.jsonl"

    # Loop until the target count is reached
    while total_entries_count < target_count: 
        api_url = f"https://api.openalex.org/topics?mailto=brookshum24@gmail.com&page={current_page}&per_page=25&select=display_name,keywords"
        # Fetch and store the data
        fetch_and_store_data(api_url, output_jsonl_file)
        current_page +=1
        total_entries_count += 25
    print(f"Total entries written to {output_jsonl_file}: {total_entries_count}")
# Out:
# Total entries with keywords: 10000
# Total entries written to topic_name_key.jsonl: 10000

# %% [markdown]
# #### 5. Triplet pairs on Topics

# %% [markdown]
# #### Triplet **display name , domain , field**  *anticipated* = [Soft-negative]

# %%
import requests
import json
import time

def fetch_and_store_topics(url, output_file): 
    # Fetch data from the URL
    response = requests.get(url)
    data = response.json()

    # Extract relevant information and store in the desired format
    results = data.get("results", [])
    formatted_data = []

    for result in results:
        display_name = result.get("display_name", "")
        domain = result.get("domain", {}).get("display_name", "")
        field = result.get("field", {}).get("display_name", "")
        
        # Create the triplet {"texts": ["display_name", "domain", "field"]}
        formatted_entry = {"texts": [display_name, domain, field]}
        formatted_data.append(formatted_entry)

    # Write to a .jsonl file
    with open(output_file, "a") as jsonl_file:
        for entry in formatted_data:
            jsonl_file.write(json.dumps(entry) + "\n")

if __name__ == "__main__":    
    # Initialize counters
    current_page = 1
    total_entries_count = 0
    target_count = 10000
    # Specify the URL and output file
    output_jsonl_file = "name_domain_field.jsonl"

    # Loop until the target count is reached
    while total_entries_count < target_count: 
        api_url = f"https://api.openalex.org/topics?mailto=brookshum24@gmail.com&page={current_page}&per_page=25&select=display_name,domain,field"
        
        # Fetch and store the data
        fetch_and_store_data(api_url, output_jsonl_file)
        current_page +=1
        total_entries_count += 25
    print(f"Total entries written to {output_jsonl_file}: {total_entries_count}")
# Out:
# Total entries written to name_domain_field.jsonl: 10000

# %% [markdown]
# #### Triplet **display name , domain , sub-field**  *anticipated* = [Hard-negative]

# %%
def fetch_and_store_topics(url, output_file): 
    # Fetch data from the URL
    response = requests.get(url)
    data = response.json()

    # Extract relevant information and store in the desired format
    results = data.get("results", [])
    formatted_data = []

    for result in results:
        display_name = result.get("display_name", "")
        domain = result.get("domain", {}).get("display_name", "")
        subfield = result.get("subfield", {}).get("display_name", "")
        
        # Create the triplet {"texts": ["display_name", "domain", "subfield"]}
        formatted_entry = {"texts": [display_name, domain, subfield]}
        formatted_data.append(formatted_entry)

     # Write to a .jsonl file
     with open(output_file, "a") as jsonl_file:
            for entry in formatted_data:
                jsonl_file.write(json.dumps(entry) + "\n") 

if __name__ == "__main__":
    # Initialize counters
    current_page = 1
    total_entries_count = 0
    target_count = 10000
    # Specify the URL and output file
    output_jsonl_file = "name_domain_subfield.jsonl"


    # Loop until the target count is reached
    while total_entries_count < target_count: 
        api_url = f"https://api.openalex.org/topics?mailto=brookshum24@gmail.com&page={current_page}&per_page=25&select=display_name,domain,subfield"
        
        # Fetch and store the data
        fetch_and_store_data(api_url, output_jsonl_file)
        current_page +=1
        total_entries_count += 25
    print(f"Total entries written to {output_jsonl_file}: {total_entries_count}")
# Out:
# Total entries written to name_domain_subfield.jsonl: 10000

# %% [markdown]
# #### Triplet **display name , field, sub-field**  *anticipated* = [Hard-negative]

# %%
def fetch_and_store_topics(url, output_file): 
    # Fetch data from the URL
    response = requests.get(url)
    data = response.json()
    # Extract relevant information and store in the desired format
    results = data.get("results", [])
    formatted_data = []

    for result in results:
        display_name = result.get("display_name", "")
        field = result.get("field", {}).get("display_name", "")
        subfield = result.get("subfield", {}).get("display_name", "")

        # Create the triplet {"texts": ["display_name", "field", "subfield"]}
        formatted_entry = {"texts": [display_name, field, subfield]}
        formatted_data.append(formatted_entry)

    # Write to a .jsonl file
    with open(output_file, "a") as jsonl_file:
        for entry in formatted_data:
            jsonl_file.write(json.dumps(entry) + "\n") 

if __name__ == "__main__":
    # Initialize counters
    current_page = 1
    total_entries_count = 0
    target_count = 10000
    # Specify the URL and output file
    output_jsonl_file = "name_field_subfield.jsonl"



    # Loop until the target count is reached
    while total_entries_count < target_count: 
        api_url = f"https://api.openalex.org/topics?mailto=brookshum24@gmail.com&page={current_page}&per_page=25&select=display_name,field, subfield"
        
        # Fetch and store the data
        fetch_and_store_data(api_url, output_jsonl_file)
        current_page +=1
        total_entries_count += 25
    print(f"Total entries written to {output_jsonl_file}: {total_entries_count}")
# Out:
# Total entries written to name_field_subfield.jsonl: 10000
